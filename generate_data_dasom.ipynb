# %%
import pandas as pd
route = [['강릉', '고양화정'],
 ['강릉', '광명'],
 ['강릉', '대전복합'],
 ['강릉', '서울경부'],
 ['강릉', '원주'],
 ['강릉', '광명'],
 ['강릉', '파주문산'],
 ['강릉', '파주운정'],
 ['강릉', '횡성'],
 ['강릉', '홍대조치원'],
 ['경주', '광주'],
 ['경주', '대전복합'],
 ['경주', '대구동양'],
 ['경주', '부산'],
 ['경주', '서울경부'],
 ['경주', '선산'],
 ['경주', '홍대조치원'],
 ['고대세종', '서울경부'],
 ['고양백석', '충주'],
 ['고양화정', '강릉'],
 ['고양화정', '광주'],
 ['고양화정', '전주'],
 ['고양화정', '정안'],
 ['고양화정', '횡성'],
 ['고흥', '서울'],
 ['고흥', '정안'],
 ['공주', '서울경부'],
 ['공주', '홍대조치원'],
 ['광명', '강릉'],
 ['광명', '속초'],
 ['광명', '오산'],
 ['광명', '전주공용'],
 ['광명', '호남제일문'],
 ['광명', '강릉'],
 ['광명', '속초'],
 ['광명', '오산'],
 ['광명', '전주공용'],
 ['광명', '호남제일문'],
 ['광양', '김해'],
 ['광양', '남청주'],
 ['광양', '당진'],
 ['광양', '대전시외'],
 ['광양', '호남제일문'],
 ['광양', '서울남부'],
 ['광양', '송도'],
 ['광양', '울산시외'],
 ['광양', '인천공항'],
 ['광양', '정안'],
 ['광양', '청사시외'],
 ['광양', '청주시외'],
 ['광양', '통영'],
 ['광주', '경주'],
 ['광주', '고양화정'],
 ['광주', '고현'],
 ['광주', '구미'],
 ['광주', '내서'],
 ['광주', '당진'],
 ['광주', '대전복합'],
 ['광주', '대전청사'],
 ['광주', '대구중앙'],
 ['광주', '정안'],
 ['광주', '마산'],
 ['광주', '부산'],
 ['광주', '서부산'],
 ['광주', '상봉'],
 ['광주', '서대구'],
 ['광주', '서울'],
 ['광주', '섬진강'],
 ['광주', '성남'],
 ['광주', '송도'],
 ['광주', '수원'],
 ['광주', '시흥'],
 ['광주', '안산'],
 ['광주', '안성'],
 ['광주', '용인'],
 ['광주', '용인신갈'],
 ['광주', '울산'],
 ['광주', '원주'],
 ['광주', '유성'],
 ['광주', '의정부'],
 ['광주', '인천'],
 ['광주', '인천공항'],
 ['광주', '장승포'],
 ['광주', '전주'],
 ['광주', '정안'],
 ['광주', '진주'],
 ['광주', '천안'],
 ['광주', '청주'],
 ['광주', '춘천'],
 ['광주', '통영'],
 ['광주', '포항'],
 ['광주', '호남제일문'],
 ['구리', '부산'],
 ['구미', '서울경부'],
 ['구미', '인천공항'],
 ['구미', '황간'],
 ['구미', '광주'],
 ['구미', '목포'],
 ['구미', '홍대조치원'],
 ['군산', '서울'],
 ['군산', '여수'],
 ['군산', '여천'],
 ['군산', '정안'],
 ['금산', '서울경부'],
 ['금산', '홍대조치원'],
 ['김제', '서울'],
 ['김제', '정안'],
 ['김천', '서울경부'],
 ['김천', '홍대조치원'],
 ['김해', '서울경부'],
 ['김해', '선산'],
 ['김해', '홍대조치원'],
 ['김해장유', '서울경부'],
 ['김해장유', '선산'],
 ['김해장유', '홍대조치원'],
 ['나주', '서울'],
 ['나주', '정안'],
 ['남원', '덕과'],
 ['남원', '서수원'],
 ['남원', '서울'],
 ['남원', '오산'],
 ['남원', '인천'],
 ['남원', '정안'],
 ['내서', '광주'],
 ['내서', '대전복합'],
 ['내서', '대구동양'],
 ['내서', '오산'],
 ['내서', '서대구'],
 ['내서', '서울경부'],
 ['내서', '선산'],
 ['내서', '성남'],
 ['노력항', '서울'],
 ['녹동', '서울'],
 ['녹동', '정안'],
 ['논산', '서울'],
 ['논산', '정안'],
 ['능주', '서울호남'],
 ['단양', '서울경부'],
 ['담양', '서울'],
 ['담양', '정안'],
 ['대전복합', '강릉'],
 ['대전복합', '경주'],
 ['대전복합', '광주'],
 ['대전복합', '내서'],
 ['대전복합', '대구동양'],
 ['대전복합', '홍대조치원'],
 ['대전복합', '마산'],
 ['대전복합', '부산'],
 ['대전복합', '상봉'],
 ['대전복합', '서대구'],
 ['대전복합', '서울경부'],
 ['대전복합', '울산'],
 ['대전복합', '인천'],
 ['대전복합', '전주공용'],
 ['대전복합', '진주'],
 ['대전복합', '천안'],
 ['대전복합', '파주문산'],
 ['대전복합', '파주운정'],
 ['대전복합', '포항'],
 ['대전복합', '호남제일문'],
 ['대전복합', '횡성'],
 ['대전청사', '광주'],
 ['대전청사', '서울경부'],
 ['대전청사', '서울호남'],
 ['대전청사', '전주'],
 ['대전청사', '파주문산'],
 ['대전청사', '파주운정'],
 ['대전청사', '호남제일문'],
 ['대전청사', '홍대조치원'],
 ['덕과', '남원'],
 ['덕과', '서수원'],
 ['덕과', '오산'],
 ['덕과', '인천'],
 ['동광양', '김해'],
 ['동광양', '남청주'],
 ['동광양', '당진'],
 ['동광양', '대전시외'],
 ['동광양', '서울남부'],
 ['동광양', '송도'],
 ['동광양', '울산시외'],
 ['동광양', '인천공항'],
 ['동광양', '정안'],
 ['동광양', '청사시외'],
 ['동광양', '청주시외'],
 ['동광양', '통영'],
 ['대구동양', '경주'],
 ['대구동양', '내서'],
 ['대구동양', '대전복합'],
 ['대구동양', '마산'],
 ['대구동양', '목포'],
 ['대구동양', '부산'],
 ['대구동양', '선산'],
 ['대구동양', '순천'],
 ['대구동양', '의정부'],
 ['대구동양', '전주공용'],
 ['대구동양', '홍대조치원'],
 ['대구한진', '고양백석'],
 ['대구한진', '김포공항'],
 ['대구한진', '김해공항'],
 ['대구한진', '마산'],
 ['대구한진', '부천'],
 ['대구한진', '서울경부'],
 ['대구한진', '선산'],
 ['대구한진', '성남'],
 ['대구한진', '세종시외'],
 ['대구한진', '세종청사'],
 ['대구한진', '송도'],
 ['대구한진', '안산'],
 ['대구한진', '울산'],
 ['대구한진', '인천'],
 ['대구한진', '인천공항'],
 ['대구한진', '천안'],
 ['대구한진', '청주'],
 ['대구한진', '평택시외'],
 ['대구한진', '홍대조치원'],
 ['대구중앙', '광주'],
 ['대구중앙', '수원'],
 ['대구중앙', '안동'],
 ['대구중앙', '영주'],
 ['대구중앙', '용인'],
 ['대구중앙', '제천'],
 ['대구중앙', '진주'],
 ['대구중앙', '춘천'],
 ['대구중앙', '홍대조치원'],
 ['동해', '서울경부'],
 ['동해', '횡성'],
 ['동해', '홍대조치원'],
 ['마산', '광주'],
 ['마산', '대구동양'],
 ['마산', '대전복합'],
 ['마산', '서대구'],
 ['마산', '서울경부'],
 ['마산', '선산'],
 ['마산', '성남'],
 ['마산', '세종시'],
 ['마산', '용인'],
 ['마산', '용인신갈'],
 ['마산', '파주문산'],
 ['마산', '파주운정'],
 ['목포', '구미'],
 ['목포', '대구동양'],
 ['목포', '서울'],
 ['목포', '수원'],
 ['목포', '인천'],
 ['목포', '인천공항'],
 ['목포', '정안'],
 ['문장', '서울'],
 ['밀양', '서울경부'],
 ['벌교', '서울'],
 ['벌교', '정안'],
 ['보성', '서울'],
 ['보성', '정안'],
 ['부산', '경주'],
 ['부산', '광주'],
 ['부산', '구리'],
 ['부산', '대전복합'],
 ['부산', '대구동양'],
 ['부산', '홍대조치원'],
 ['부산', '서울경부'],
 ['부산', '선산'],
 ['부산', '성남'],
 ['부산', '세종시'],
 ['부산', '순천'],
 ['부산', '여수'],
 ['부산', '여천'],
 ['부산', '용인'],
 ['부산', '용인신갈'],
 ['부산', '의정부'],
 ['부산', '인천'],
 ['부산', '전주공용'],
 ['부산', '청주'],
 ['서부산', '광주'],
 ['서부산', '서울경부'],
 ['서부산', '선산'],
 ['서부산', '섬진강'],
 ['서부산', '성남'],
 ['서부산', '세종시'],
 ['서부산', '순천종합'],
 ['서부산', '여수'],
 ['서부산', '여천'],
 ['서부산', '용인'],
 ['서부산', '용인신갈'],
 ['서부산', '인천'],
 ['서부산', '홍대조치원'],
 ['삼척', '서울경부'],
 ['삼척', '횡성'],
 ['삼척', '홍대조치원'],
 ['삼호', '서울'],
 ['삼호', '정안'],
 ['상봉', '광주'],
 ['상봉', '대전복합'],
 ['상봉', '전주'],
 ['상봉', '정안'],
 ['상봉', '청주'],
 ['상주', '서울경부'],
 ['상주', '홍대조치원'],
 ['서대구', '광주'],
 ['서대구', '내서'],
 ['서대구', '대전복합'],
 ['서대구', '홍대조치원'],
 ['서대구', '마산'],
 ['서대구', '서울경부'],
 ['서대구', '선산'],
 ['서대구', '성남'],
 ['서대구', '순천'],
 ['서대구', '의정부'],
 ['서대구', '인천'],
 ['서대구', '전주'],
 ['서대구', '진주'],
 ['서대구', '청주'],
 ['서대구', '춘천'],
 ['서수원', '남원'],
 ['서수원', '덕과'],
 ['서수원', '오산'],
 ['서수원', '인천'],
 ['서울경부', '선택'],
 ['서울경부', '강릉'],
 ['서울경부', '경주'],
 ['서울경부', '고대세종'],
 ['서울경부', '공주'],
 ['서울경부', '구미'],
 ['서울경부', '금산'],
 ['서울경부', '김천'],
 ['서울경부', '김해'],
 ['서울경부', '김해장유'],
 ['서울경부', '내서'],
 ['서울경부', '대전복합'],
 ['서울경부', '대전청사'],
 ['서울경부', '대구한진'],
 ['서울경부', '동해'],
 ['서울경부', '마산'],
 ['서울경부', '밀양'],
 ['서울경부', '부산'],
 ['서울경부', '서부산'],
 ['서울경부', '삼척'],
 ['서울경부', '상주'],
 ['서울경부', '서대구'],
 ['서울경부', '선산'],
 ['서울경부', '세종시'],
 ['서울경부', '세종청사'],
 ['서울경부', '속초'],
 ['서울경부', '천안아산역'],
 ['서울경부', '아산서부'],
 ['서울경부', '아산온양'],
 ['서울경부', '안성'],
 ['서울경부', '안성공도'],
 ['서울경부', '안성대림'],
 ['서울경부', '안성중대'],
 ['서울경부', '안성풍림'],
 ['서울경부', '안성한경'],
 ['서울경부', '안성회관'],
 ['서울경부', '양양'],
 ['서울경부', '여주'],
 ['서울경부', '영천'],
 ['서울경부', '용인'],
 ['서울경부', '용인유방'],
 ['서울경부', '울산'],
 ['서울경부', '원주'],
 ['서울경부', '이천'],
 ['서울경부', '인삼랜드'],
 ['서울경부', '점촌'],
 ['서울경부', '제천'],
 ['서울경부', '조치원'],
 ['서울경부', '진주'],
 ['서울경부', '진주혁신도시'],
 ['서울경부', '창원'],
 ['서울경부', '창원역'],
 ['서울경부', '천안'],
 ['서울경부', '청주'],
 ['서울경부', '통영'],
 ['서울경부', '평택'],
 ['서울경부', '평택대'],
 ['서울경부', '포항'],
 ['서울경부', '황간'],
 ['서울경부', '횡성'],
 ['서울경부', '홍대조치원'],
 ['서울경부', '안동'],
 ['서울경부', '영덕'],
 ['서울경부', '영주'],
 ['서울경부', '풍기'],
 ['서울경부', '예천'],
 ['서울경부', '경북도청'],
 ['서울경부', '울진'],
 ['서울경부', '광비'],
 ['서울경부', '삼근'],
 ['서울경부', '평해'],
 ['서울경부', '춘천'],
 ['서울경부', '철원'],
 ['서울경부', '장현'],
 ['서울경부', '포천'],
 ['서울경부', '운천'],
 ['서울경부', '신철원'],
 ['서울경부', '영월'],
 ['서울경부', '영천망정동'],
 ['서울경부', '단양'],
 ['서울경부', '세종연구단지'],
 ['선산', '경주'],
 ['선산', '김해'],
 ['선산', '김해장유'],
 ['선산', '내서'],
 ['선산', '대구한진'],
 ['선산', '대구동양'],
 ['선산', '마산'],
 ['선산', '부산'],
 ['선산', '서부산'],
 ['선산', '서대구'],
 ['선산', '영천'],
 ['선산', '울산'],
 ['선산', '창원'],
 ['선산', '창원역'],
 ['선산', '포항'],
 ['선산', '경주'],
 ['선산', '서울경부'],
 ['선산', '성남'],
 ['선산', '용인'],
 ['선산', '용인신갈'],
 ['선산', '의정부'],
 ['선산', '인천'],
 ['선산', '천안'],
 ['선산', '청주'],
 ['선산', '파주문산'],
 ['선산', '파주운정'],
 ['성남', '광주'],
 ['성남', '내서'],
 ['성남', '대구한진'],
 ['성남', '마산'],
 ['성남', '부산'],
 ['성남', '서부산'],
 ['성남', '서대구'],
 ['성남', '선산'],
 ['성남', '인삼랜드'],
 ['성남', '전주'],
 ['성남', '정안'],
 ['성남', '진주'],
 ['성남', '창원'],
 ['성남', '창원역'],
 ['성남', '통영'],
 ['세종연구단지', '서울경부'],
 ['세종시', '마산'],
 ['세종시', '부산'],
 ['세종시', '서부산'],
 ['세종시', '서울경부'],
 ['세종시', '창원'],
 ['세종시', '홍대조치원'],
 ['세종청사', '서울경부'],
 ['세종청사', '홍대조치원'],
 ['속초', '광명'],
 ['속초', '홍대조치원'],
 ['속초', '서울경부'],
 ['속초', '인천'],
 ['속초', '광명'],
 ['속초', '횡성'],
 ['수원', '광주'],
 ['수원', '대전복합'],
 ['수원', '목포'],
 ['수원', '순천종합'],
 ['수원', '여수'],
 ['수원', '여천'],
 ['수원', '인삼랜드'],
 ['수원', '정안'],
 ['수원', '진주'],
 ['순창', '서울'],
 ['순천', '대구동양'],
 ['순천', '부산'],
 ['순천', '서대구'],
 ['순천', '서울'],
 ['순천', '인천'],
 ['순천', '정안'],
 ['순천종합', '김해'],
 ['순천종합', '남청주'],
 ['순천종합', '당진'],
 ['순천종합', '대전시외'],
 ['순천종합', '서부산'],
 ['순천종합', '송도'],
 ['순천종합', '수원'],
 ['순천종합', '신갈시외'],
 ['순천종합', '영통'],
 ['순천종합', '울산시외'],
 ['순천종합', '인천공항'],
 ['순천종합', '청사시외'],
 ['순천종합', '청주시외'],
 ['순천종합', '통영'],
 ['시흥', '정안'],
 ['시흥', '광주'],
 ['신갈시외', '순천종합'],
 ['천안아산역', '서울경부'],
 ['천안아산역', '홍대조치원'],
 ['아산서부', '서울경부'],
 ['아산서부', '홍대조치원'],
 ['아산온양', '서울경부'],
 ['아산온양', '인천'],
 ['아산온양', '홍대조치원'],
 ['안성', '광주'],
 ['안성', '서울경부'],
 ['안성', '정안'],
 ['안성', '홍대조치원'],
 ['안성공도', '서울경부'],
 ['안성공도', '홍대조치원'],
 ['안성대림', '서울경부'],
 ['안성대림', '홍대조치원'],
 ['안성중대', '광주'],
 ['안성중대', '서울경부'],
 ['안성중대', '정안'],
 ['안성중대', '홍대조치원'],
 ['안성풍림', '광주'],
 ['안성풍림', '서울경부'],
 ['안성풍림', '정안'],
 ['안성풍림', '홍대조치원'],
 ['안성한경', '서울경부'],
 ['안성한경', '홍대조치원'],
 ['안성회관', '서울경부'],
 ['안성회관', '홍대조치원'],
 ['양양', '서울경부'],
 ['양양', '홍대조치원'],
 ['여수', '군산'],
 ['여수', '남청주'],
 ['여수', '당진'],
 ['여수', '대전시외'],
 ['여수', '대전시외'],
 ['여수', '부산'],
 ['여수', '서부산'],
 ['여수', '서울'],
 ['여수', '송도'],
 ['여수', '수원'],
 ['여수', '울산시외'],
 ['여수', '인천'],
 ['여수', '인천공항'],
 ['여수', '정안'],
 ['여수', '청사시외'],
 ['여수', '청주시외'],
 ['여수', '통영'],
 ['여주', '서울경부'],
 ['여주', '홍대조치원'],
 ['여천', '군산'],
 ['여천', '부산'],
 ['여천', '서부산'],
 ['여천', '서울'],
 ['여천', '수원'],
 ['여천', '인천'],
 ['여천', '정안'],
 ['연무대', '서울'],
 ['연무대', '정안'],
 ['영산포', '서울'],
 ['영산포', '정안'],
 ['영암', '서울'],
 ['영주', '서울경부'],
 ['영주', '동대구'],
 ['영천', '서울경부'],
 ['영천망정동', '서울경부'],
 ['예천', '서울경부'],
 ['오산', '광명'],
 ['오산', '남원'],
 ['오산', '덕과'],
 ['오산', '서수원'],
 ['오산', '인천'],
 ['오산', '전주공용'],
 ['오산', '광명'],
 ['오산', '호남제일문'],
 ['용인', '광주'],
 ['용인', '마산'],
 ['용인', '부산'],
 ['용인', '서부산'],
 ['용인', '서울경부'],
 ['용인', '선산'],
 ['용인', '인삼랜드'],
 ['용인', '정안'],
 ['용인', '진주'],
 ['용인', '창원'],
 ['용인', '홍대조치원'],
 ['용인신갈', '광주'],
 ['용인신갈', '마산'],
 ['용인신갈', '부산'],
 ['용인신갈', '서부산'],
 ['용인신갈', '선산'],
 ['용인신갈', '인삼랜드'],
 ['용인신갈', '정안'],
 ['용인신갈', '진주'],
 ['용인신갈', '창원'],
 ['용인신갈', '홍대조치원'],
 ['용인유방', '서울경부'],
 ['용인유방', '홍대조치원'],
 ['울산', '광주'],
 ['울산', '대전복합'],
 ['울산', '대구한진'],
 ['울산', '서울경부'],
 ['울산', '선산'],
 ['울산', '전주'],
 ['울산', '천안'],
 ['울산', '홍대조치원'],
 ['울산신복', '광주'],
 ['울산신복', '대전복합'],
 ['울산신복', '서울경부'],
 ['울산신복', '선산'],
 ['울산신복', '전주'],
 ['울산신복', '천안'],
 ['울산신복', '홍대조치원'],
 ['원주', '강릉'],
 ['원주', '광주'],
 ['원주', '서울경부'],
 ['원주', '홍대조치원'],
 ['유성', '광주'],
 ['유성', '서울'],
 ['의정부', '광주'],
 ['의정부', '대구동양'],
 ['의정부', '부산'],
 ['의정부', '서대구'],
 ['의정부', '선산'],
 ['의정부', '정안'],
 ['이천', '서울경부'],
 ['이천', '홍대조치원'],
 ['익산', '서울'],
 ['익산', '안산'],
 ['익산', '인천'],
 ['익산', '정안'],
 ['익산팔봉', '서울'],
 ['익산팔봉', '안산'],
 ['익산팔봉', '인천'],
 ['익산팔봉', '정안'],
 ['인삼랜드', '대전시외'],
 ['인삼랜드', '홍대조치원'],
 ['인삼랜드', '서울경부'],
 ['인삼랜드', '성남'],
 ['인삼랜드', '수원'],
 ['인삼랜드', '용인'],
 ['인삼랜드', '용인신갈'],
 ['인삼랜드', '인천'],
 ['인삼랜드', '진주'],
 ['인삼랜드', '통영'],
 ['인삼랜드', '홍대조치원'],
 ['인천', '광주'],
 ['인천', '남원'],
 ['인천', '대전복합'],
 ['인천', '덕과'],
 ['인천', '대구한진'],
 ['인천', '목포'],
 ['인천', '부산'],
 ['인천', '서부산'],
 ['인천', '서대구'],
 ['인천', '선산'],
 ['인천', '속초'],
 ['인천', '순천'],
 ['인천', '여수'],
 ['인천', '여천'],
 ['인천', '익산'],
 ['인천', '인삼랜드'],
 ['인천', '전주공용'],
 ['인천', '정안'],
 ['인천', '진주'],
 ['인천', '횡성'],
 ['장성', '서울'],
 ['전주', '고양화정'],
 ['전주', '광주'],
 ['전주', '대전복합'],
 ['전주', '대전청사'],
 ['전주', '대구동양'],
 ['전주', '부산'],
 ['전주', '상봉'],
 ['전주', '서대구'],
 ['전주', '서울'],
 ['전주', '성남'],
 ['전주', '울산'],
 ['전주', '인천'],
 ['전주', '광명'],
 ['전주', '오산'],
 ['전주', '정안'],
 ['전주', '광명'],
 ['호남제일문', '고양화정'],
 ['호남제일문', '광명'],
 ['호남제일문', '광주'],
 ['호남제일문', '대전복합'],
 ['호남제일문', '대전청사'],
 ['호남제일문', '상봉'],
 ['호남제일문', '서울'],
 ['호남제일문', '성남'],
 ['호남제일문', '오산'],
 ['호남제일문', '인천'],
 ['호남제일문', '정안'],
 ['호남제일문', '광명'],
 ['점촌', '서울경부'],
 ['점촌', '홍대조치원'],
 ['정안', '고양화정'],
 ['정안', '홍대조치원'],
 ['정안', '상봉'],
 ['정안', '서울호남'],
 ['정안', '성남'],
 ['정안', '수원'],
 ['정안', '시흥'],
 ['정안', '안산'],
 ['정안', '안성'],
 ['정안', '용인'],
 ['정안', '용인신갈'],
 ['정안', '의정부'],
 ['정안', '인천'],
 ['정안', '천안'],
 ['정안', '광주'],
 ['정안', '목포'],
 ['정안', '순천'],
 ['정안', '여수'],
 ['정안', '여천'],
 ['정안', '익산'],
 ['정안', '전주공용'],
 ['정안', '호남제일문'],
 ['정읍', '광주'],
 ['정읍', '서울'],
 ['정읍', '정안'],
 ['제천', '서울경부'],
 ['조치원', '서울경부'],
 ['조치원', '홍대조치원'],
 ['진주', '광주'],
 ['진주', '대구중앙'],
 ['진주', '대전복합'],
 ['진주', '홍대조치원'],
 ['진주', '서대구'],
 ['진주', '서울경부'],
 ['진주', '성남'],
 ['진주', '수원'],
 ['진주', '용인'],
 ['진주', '용인신갈'],
 ['진주', '인삼랜드'],
 ['진주', '인천'],
 ['진주혁신도시', '서울경부'],
 ['진주혁신도시', '원주'],
 ['진주혁신도시', '인삼랜드'],
 ['창원', '홍대조치원'],
 ['창원', '서울경부'],
 ['창원', '선산'],
 ['창원', '성남'],
 ['창원', '세종시'],
 ['창원', '용인'],
 ['창원', '용인신갈'],
 ['창원', '파주문산'],
 ['창원', '파주운정'],
 ['창원역', '홍대조치원'],
 ['창원역', '서울경부'],
 ['창원역', '선산'],
 ['창원역', '성남'],
 ['청주', '광주'],
 ['청주', '대구한진'],
 ['청주', '홍대조치원'],
 ['청주', '부산'],
 ['청주', '상봉'],
 ['청주', '서대구'],
 ['청주', '서울경부'],
 ['청주', '선산'],
 ['춘천', '광주'],
 ['춘천', '대구중앙'],
 ['춘천', '서대구'],
 ['춘천', '서울경부'],
 ['통영', '광양'],
 ['통영', '광주'],
 ['통영', '대전시외'],
 ['통영', '동광양'],
 ['통영', '서울경부'],
 ['통영', '서울남부'],
 ['통영', '성남'],
 ['통영', '순천종합'],
 ['통영', '여수'],
 ['통영', '인삼랜드'],
 ['통영', '홍대조치원'],
 ['파주문산', '강릉'],
 ['파주문산', '대전복합'],
 ['파주문산', '대전청사'],
 ['파주문산', '마산'],
 ['파주문산', '선산'],
 ['파주문산', '창원'],
 ['파주문산', '횡성'],
 ['파주운정', '강릉'],
 ['파주운정', '대전복합'],
 ['파주운정', '대전청사'],
 ['파주운정', '마산'],
 ['파주운정', '선산'],
 ['파주운정', '창원'],
 ['파주운정', '횡성'],
 ['평택', '서울경부'],
 ['평택', '홍대조치원'],
 ['평택대', '서울경부'],
 ['평택대', '홍대조치원'],
 ['포항', '광주'],
 ['포항', '대전복합'],
 ['포항', '서울경부'],
 ['포항', '선산'],
 ['포항', '홍대조치원'],
 ['함평', '서울'],
 ['해남', '서울'],
 ['해남', '정안'],
 ['화순', '서울호남'],
 ['황간', '서울경부'],
 ['황간', '홍대조치원'],
 ['홍대조치원', '서울경부'],
 ['회진', '서울'],
 ['횡성', '강릉'],
 ['횡성', '동해'],
 ['횡성', '삼척'],
 ['횡성', '속초'],
 ['횡성', '홍대조치원'],
 ['횡성', '고양화정'],
 ['횡성', '대전복합'],
 ['횡성', '홍대조치원'],
 ['횡성', '서울경부'],
 ['횡성', '인천'],
 ['횡성', '파주문산'],
 ['인천공항', '광주'],
 ['인천공항', '목포'],
 ['인천공항', '여수'],
 ['인천공항', '순천시외'],
 ['인천공항', '동광양'],
 ['인천공항', '광양'],
 ['천안', '서울경부'],
 ['천안', '대전복합'],
 ['천안', '울산'],
 ['천안', '선산'],
 ['천안', '광주'],
 ['천안', '익산'],
 ['천안', '정안'],
 ['센트럴', '김제'],
 ['센트럴', '연무대'],
 ['센트럴', '논산'],
 ['센트럴', '강진'],
 ['센트럴', '광주'],
 ['센트럴', '군산'],
 ['센트럴', '남원'],
 ['센트럴', '고흥'],
 ['센트럴', '녹동'],
 ['센트럴', '담양'],
 ['센트럴', '목포'],
 ['센트럴', '보성'],
 ['센트럴', '벌교'],
 ['센트럴', '순천'],
 ['센트럴', '여수'],
 ['센트럴', '여천'],
 ['센트럴', '영광'],
 ['센트럴', '나주'],
 ['센트럴', '영산포'],
 ['센트럴', '완도'],
 ['센트럴', '유성'],
 ['센트럴', '익산'],
 ['센트럴', '전주'],
 ['센트럴', '정읍'],
 ['센트럴', '진도'],
 ['센트럴', '해남'],
 ['센트럴', '정안'],
 ['안산', '광주'],
 ['안산', '익산'],
 ['안산', '정안'],
 ['정안', '광주'],
 ['정안', '익산'],
 ['정안', '목포'],
 ['정안', '전주공용'],
 ['정안', '김제'],
 ['정안', '연무대'],
 ['정안', '논산'],
 ['정안', '강진'],
 ['정안', '군산'],
 ['정안', '남원'],
 ['정안', '고흥'],
 ['정안', '녹동'],
 ['정안', '담양'],
 ['정안', '보성'],
 ['정안', '벌교'],
 ['정안', '순천'],
 ['정안', '여수'],
 ['정안', '영광'],
 ['정안', '나주'],
 ['정안', '영산포'],
 ['정안', '완도'],
 ['정안', '정읍'],
 ['정안', '진도'],
 ['정안', '해남']]

# %%
import numpy as np
import random 

def gen_data():

  def make_data():
    date = ['이번주','다음주','월요일','화요일','수요일','목요일','금요일','토요일','일요일','익일','금일','명일','내일','모레','내일 모레','보름']
    person = ['성인','어른','어린이','아기','애기','초등학생','청소년','중학생','고등학생']
    dep_time = ['2시에','낮','오후','밤','저녁','5분 뒤','5분 후','1시간 뒤','1시간 후','1시간 10분 뒤','1시간 10분 후','1시간10분뒤','1시간10분후','1시간뒤','1시간후','현재 시간 기준']
    arr_time = ['4시','8시안으로','자정안에','오늘8시안에','8시까지','낮','오후','오전','밤','저녁','오늘 8시안에','오늘 8시까지','오후 8시','오전 8시','오전까지','오후까지','밤까지','저녁까지']
    dep = []
    arr = []
    for i in range(len(route)):
        dep.append(route[i][0])
        arr.append(route[i][1])

    passenger = pd.Series([dep,arr,date,person,dep_time,arr_time], index = ["dep","arr","date","person","dep_time","arr_time"])

    return passenger

  passenger = make_data()

  def get_info(passenger,i):
    return '/' + passenger.index[i] + ';' + random.choice(passenger[i]) + '/'

  # case1) 목적지만 얘기하는 상황 

  route_list1_1 = list(set([
              get_info(passenger,1) + "으로 가는 버스 예약해줘."              
          for i in range(50)]))
  
  route_list1_2 = list(set([
              "목적지는" +get_info(passenger,1) + "인 버스 예약해주세요."
         for i in range(50)]))
  
  route_list1_3 = list(set([
               get_info(passenger,1) + "으로 가고싶어."
         for i in range(50)]))
  
  route_list1_4 = list(set([
               get_info(passenger,1) + "도착 버스 예약해줘."
         for i in range(50)]))
  
  route_list1_5 = list(set([
              "도착지는" +get_info(passenger,1) + "인 티켓 발행해주세요."
         for i in range(50)]))
  
  route_list1_6 = list(set([
              get_info(passenger,1) + "행 티켓 발행해주세요."
         for i in range(50)]))
  
  # case2) yes -> 인원 선택하는 케이스 

  route_list2_1 = list(set([
             get_info(passenger,3) + str(random.randint(1,4)) +"명 입니다."
         for i in range(50)]))
  
  route_list2_2 = list(set([
             "인원은 "+get_info(passenger,3) + str(random.randint(1,4)) +"명," +get_info(passenger,3) + str(random.randint(1,4)) +"명 입니다."
         for i in range(50)]))
  
  route_list2_3 = list(set([
             get_info(passenger,3) + str(random.randint(1,4)) +"명"
         for i in range(50)]))
  
  # case3) no -> 변경하고자 할 때 
    # 출발지 변경할 때 
  route_list3_1 = list(set([
             "출발지는" + get_info(passenger,0) +"으로 해주세요." 
         for i in range(50)]))
  
  route_list3_2 =  list(set([
             get_info(passenger,0) +"에서 출발할래." 
         for i in range(50)]))
  
  route_list3_3 =  list(set([
             get_info(passenger,0) +"으로 변경해줘." 
         for i in range(50)]))
  
    # 날짜 변경할 때 
  route_list4_1 = list(set([
             get_info(passenger,2) +"으로 변경해줘." 
         for i in range(50)]))

  route_list4_2 = list(set([
             "날짜는 " +get_info(passenger,2) +"으로 변경해주세요." 
         for i in range(50)]))
  
  route_list4_3 = list(set([
             get_info(passenger,2) +"일정으로 예약할래." 
         for i in range(50)]))

    # 시간 변경할 때 
  route_list5_1 = list(set([
             "출발 시간은" + get_info(passenger,4) +"으로 변경해줘." 
         for i in range(50)]))
  
  route_list5_2 =  list(set([
             get_info(passenger,4) +"출발로 변경해주세요." 
         for i in range(50)]))
  
  route_list5_3 =  list(set([
              get_info(passenger,4) +"시간으로 바꿔줘." 
         for i in range(50)]))
  
  route_list5_4 =  list(set([
             "도착 시간은" + get_info(passenger,5) +"으로 변경해줘." 
         for i in range(50)]))
  
  route_list5_5 =  list(set([
              get_info(passenger,5) +"으로 변경해줘." 
         for i in range(50)]))

  # 출발지 + 날짜 / 출발지 + 시간 / 날짜 + 시간 변경 
  route_list6_1 = list(set([
             "출발지는" + get_info(passenger,0) +"이고," + "날짜는" + get_info(passenger,2) +"으로 바꿀래."
         for i in range(50)]))
  
  route_list6_2 = list(set([
             "출발지는" + get_info(passenger,0) +"이고," + "시간은" + get_info(passenger,4) +"으로 변경해주세요."
         for i in range(50)]))
  
  route_list6_3 = list(set([
              get_info(passenger,0) +"에서 출발하고," + "도착 시간을" + get_info(passenger,5) +"로 해줘."
         for i in range(50)]))

  route_list6_4 = list(set([
             "날짜는" + get_info(passenger,2) +"이고," + "출발 시간은" + get_info(passenger,4) +"으로 해주세요."
         for i in range(50)]))
  
  # 출발지 + 날짜 + 시간 변경 

  route_list7_1 = list(set([
             "출발지는" + get_info(passenger,0) +"이고," + "날짜랑 시간은" + get_info(passenger,2) + get_info(passenger,4) + "로 해줘." 
         for i in range(50)]))

  route_list7_2 = list(set([
             get_info(passenger,0) +"에서 출발할거고" + get_info(passenger,2) + "에" + get_info(passenger,5) + "으로 변경." 
         for i in range(50)]))
  
  route_list7_3 = list(set([
             get_info(passenger,0) +"에서" + get_info(passenger,2) + "에" + get_info(passenger,4) + "로 변경해주세요." 
         for i in range(50)]))

  # 사용자의 대화 예측 
  route_list0 = ['할인 되나요?',
                 '카드 할인 있나요?',
                 '할인 대상에 포함되나요?'
                 '다시 예약할게요.',
                 '변경하고 싶어요.',
                 '출발지 변경할래요.',
                 '날짜 변경하고 싶어요.',
                 '다른 시간대 있나요?',
                 '좌석 변경하고 싶어요.',
                 '환불해주세요.',
                 '환불할래.',
                 '다시 예약 할래.',
                 '예매 정보좀 보여줘.',
                 '잠시만요.',
                 '다시 말씀해주세요.',
                 '다 된건가요?',
                 '휠체어석 있나요?',
                 '잔여 좌석이 있나요?',
                 '총 얼마인가요?',
                 '인원 추가하고 싶어요.',
                 '할인 이벤트 있어요?',
                 '저 죄송한데 다시 예약할게요.',
                 '예약 안할래요.',
                 '소요 시간이 어떻게 되나요?',
                 '목적지까지 얼마나 걸릴까요?'
                 
  ]

  route_list = (route_list1_1 + route_list1_2 + route_list1_3 + route_list1_4 + route_list1_5 + 
              route_list2_1 + route_list2_2 + route_list2_3+ route_list3_1+route_list3_2+route_list3_3+
              route_list4_1 + route_list4_2 + route_list4_3+route_list5_1 +route_list5_2 +route_list5_3+route_list5_4+route_list5_1+
              route_list6_1+route_list6_2+route_list6_3+route_list6_4+route_list7_1+route_list7_2+route_list7_3 +route_list0 )

  return route_list

# %%
route = gen_data()

# %%
print(route)
# Out:
# ['/arr;당진/으로 가는 버스 예약해줘.', '/arr;인천/으로 가는 버스 예약해줘.', '/arr;인천공항/으로 가는 버스 예약해줘.', '/arr;호남제일문/으로 가는 버스 예약해줘.', '/arr;진주/으로 가는 버스 예약해줘.', '/arr;영주/으로 가는 버스 예약해줘.', '/arr;전주공용/으로 가는 버스 예약해줘.', '/arr;순천/으로 가는 버스 예약해줘.', '/arr;정읍/으로 가는 버스 예약해줘.', '/arr;서울/으로 가는 버스 예약해줘.', '/arr;경주/으로 가는 버스 예약해줘.', '/arr;울산시외/으로 가는 버스 예약해줘.', '/arr;울산/으로 가는 버스 예약해줘.', '/arr;고대세종/으로 가는 버스 예약해줘.', '/arr;광주/으로 가는 버스 예약해줘.', '/arr;서대구/으로 가는 버스 예약해줘.', '/arr;익산/으로 가는 버스 예약해줘.', '/arr;홍대조치원/으로 가는 버스 예약해줘.', '/arr;전주/으로 가는 버스 예약해줘.', '/arr;상봉/으로 가는 버스 예약해줘.', '/arr;대전복합/으로 가는 버스 예약해줘.', '/arr;정안/으로 가는 버스 예약해줘.', '/arr;선산/으로 가는 버스 예약해줘.', '/arr;풍기/으로 가는 버스 예약해줘.', '/arr;예천/으로 가는 버스 예약해줘.', '/arr;서울경부/으로 가는 버스 예약해줘.', '/arr;송도/으로 가는 버스 예약해줘.', '/arr;청주/으로 가는 버스 예약해줘.', '/arr;강릉/으로 가는 버스 예약해줘.', '/arr;마산/으로 가는 버스 예약해줘.', '/arr;운천/으로 가는 버스 예약해줘.', '/arr;강진/으로 가는 버스 예약해줘.', '/arr;오산/으로 가는 버스 예약해줘.', '/arr;수원/으로 가는 버스 예약해줘.', '목적지는/arr;서대구/인 버스 예약해주세요.', '목적지는/arr;정안/인 버스 예약해주세요.', '목적지는/arr;남청주/인 버스 예약해주세요.', '목적지는/ar
# ...
