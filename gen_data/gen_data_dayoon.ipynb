# %%
import pandas as pd
import numpy as np
import random
from datetime import datetime

dep = pd.read_csv('/content/route.txt', sep = ',')
dep_list=dep.iloc[:,0].unique().tolist()
route=dep.values.tolist()

# %%
dep
# Out:
#     dep   arr
# 0    강릉  고양화정
# 1    강릉    광명
# 2    강릉  대전복합
# 3    강릉  서울경부
# 4    강릉    원주
# ..   ..   ...
# 863  정안   영산포
# 864  정안    완도
# 865  정안    정읍
# 866  정안    진도
# 867  정안    해남
#
# [868 rows x 2 columns]

# %%
def date_range(start, end):
    start = datetime.strptime(start, "%m월 %d일")
    end = datetime.strptime(end, "%m월 %d일")
    dates = [date.strftime("%-m월 %-d일") for date in pd.date_range(start, periods=(end-start).days+1)]
    return dates

# %%
date = date_range("1월 1일", "12월 31일")
people=['일반',	'중고생',	'아동',	'국가유공자',	'성인',	'어른',	'어린이',	'아기',	'애기',	'초등학생',	'청소년',	'중학생',	'고등학생']
now=['지금','당장','빨리','현재','최대한 빨리','가장 빠른','가장 빨리']
forward_time=['낮','오전','오후','밤','저녁','아침','새벽']
date_exact=['오늘','익일','금일','명일','내일','모레','내일 모레','보름']
date_not_exact=['이번주','다음주','다다음주']
date_not_exact_with_int=['주 뒤','일 뒤','주일 뒤']
day=['월요일','화요일','수요일','목요일','금요일','토요일','일요일']

# %%
some_date=pd.Series([date, date_exact, now], index=['date', 'date_exact', 'now'])
some_date
# Out:
# date          [1월 1일, 1월 2일, 1월 3일, 1월 4일, 1월 5일, 1월 6일, 1월 ...
# date_exact                  [오늘, 익일, 금일, 명일, 내일, 모레, 내일 모레, 보름]
# now                      [지금, 당장, 빨리, 현재, 최대한 빨리, 가장 빠른, 가장 빨리]
# dtype: object

# %%
def get_route():
  st=random.choice(dep_list)
  match=[i for i in range(len(route)) if route[i][0]==st]
  end=route[random.choice(match)][1]
  return "/DEP;"+st+'/', "/ARR;"+end+'/'

def get_date(i):
  return '/DATE;'+random.choice(some_date[i])+'/'

#ex.이번주 월요일
def get_date_with_day():
  return '/DATE;'+random.choice(date_not_exact)+' '+random.choice(day)+'/'

#ex.1주일 뒤
def get_date_not_exact_int():
  return '/DATE;'+str(np.random.randint(1,6))+random.choice(date_not_exact_with_int)+'/'

#ex. 낮 12시
def get_dtime_hour():
  return '/DEP_TIME;'+random.choice(forward_time)+' '+str(np.random.randint(1,12))+'시'+'/'

#ex. 18시
def get_dtime_full_hour():
  return '/DEP_TIME;'+str(np.random.randint(0,24))+'시'+'/'

#ex. 낮 12시 30분, 낮 12시 반
def get_dtime_hour_exact_min():
  return '/DEP_TIME;'+random.choice(forward_time)+' '+str(np.random.randint(1,12))+'시'+random.choice(['반',str(np.random.randint(1,60))+'분'])+'/'

#ex. 18시 30분
def get_dtime_full_hour_exact_min():
  return '/DEP_TIME;'+str(np.random.randint(0,24))+'시'+random.choice(['반',str(np.random.randint(1,60))+'분'])+'/'

#ex. 12시간 뒤
def get_dtime_hour_later():
  return '/DEP_TIME;'+str(np.random.randint(1,12))+random.choice(['시간 뒤','시간 후'])+'/'

#ex. 30분 뒤
def get_dtime_min_later():
  return '/DEP_TIME;'+str(np.random.randint(1,60))+random.choice(['분 뒤','분 후'])+'/'

def get_atime_hour():
  return '/ARR_TIME;'+random.choice(forward_time)+' '+str(np.random.randint(1,12))+'시'+random.choice(['',' 반'])+'/'

def get_atime_hour_exact_min():
  return '/ARR_TIME;'+random.choice(forward_time)+' '+str(np.random.randint(1,12))+'시'+str(np.random.randint(1,60))+'분'+'/'

def get_atime_hour_later():
  return '/ARR_TIME;'+str(np.random.randint(1,12))+random.choice(['시간 뒤','시간 후'])+'/'

def get_atime_full_hour():
  return '/ARR_TIME;'+str(np.random.randint(0,24))+'시'+'/'

def get_atime_full_hour_exact_min():
  return '/ARR_TIME;'+str(np.random.randint(0,24))+'시'+random.choice(['반',str(np.random.randint(1,60))+'분'])+'/'

# %%
reserve=['예약','예매']
ending=['할래','해줘','해','하려 해','하려하는데 표 있어?']

# %%
bus_list_d_1=[]
for i in range(800):
  start, end = get_route()
  bus_list_d_1.append(start+'에서 '+end+'로 가는 버스 '+random.choice(reserve)+random.choice(ending))

bus_list_d_2=[]
for i in range(800):
  start, end = get_route()
  bus_list_d_2.append(end+'로 가는 버스 '+random.choice(reserve)+random.choice(ending)+'. '+start+'에서 출발할꺼야')

bus_list_d_3=[]
for i in range(800):
  start, end = get_route()
  bus_list_d_3.append(end+'로 가는 버스 '+random.choice(reserve)+random.choice(ending)+'. '+start+'에서 출발하는 걸로')

bus_list_d_4=[]
for i in range(800):
  start, end = get_route()
  bus_list_d_4.append(end+'로 가는 버스 '+random.choice(reserve)+random.choice(ending)+'. '+start+'출발')

bus_list_d_5=[]
for i in range(800):
  start, end = get_route()
  bus_list_d_5.append(start+'에서 출발해서 '+end+'로 도착하는 버스 '+random.choice(reserve)+random.choice(ending))

bus_list_d_6=[]
for i in range(800):
  start, end = get_route()
  bus_list_d_6.append(start+'출발 '+end+'도착 버스 '+random.choice(reserve)+random.choice(ending))

bus_list=bus_list_d_1+bus_list_d_2+bus_list_d_3+bus_list_d_4+bus_list_d_5+bus_list_d_6

bus_list
# Out:
# ['/DEP;홍대조치원/에서 /ARR;서울경부/로 가는 버스 예약하려 해',
#  '/DEP;안성중대/에서 /ARR;서울경부/로 가는 버스 예매할래',
#  '/DEP;삼척/에서 /ARR;횡성/로 가는 버스 예약해',
#  '/DEP;금산/에서 /ARR;서울경부/로 가는 버스 예약하려하는데 표 있어?',
#  '/DEP;광주/에서 /ARR;섬진강/로 가는 버스 예매하려 해',
#  '/DEP;오산/에서 /ARR;호남제일문/로 가는 버스 예약해줘',
#  '/DEP;광명/에서 /ARR;전주공용/로 가는 버스 예약하려 해',
#  '/DEP;호남제일문/에서 /ARR;오산/로 가는 버스 예약할래',
#  '/DEP;통영/에서 /ARR;홍대조치원/로 가는 버스 예매해',
#  '/DEP;덕과/에서 /ARR;남원/로 가는 버스 예약하려하는데 표 있어?',
#  '/DEP;센트럴/에서 /ARR;논산/로 가는 버스 예매해줘',
#  '/DEP;서울경부/에서 /ARR;동해/로 가는 버스 예약할래',
#  '/DEP;의정부/에서 /ARR;정안/로 가는 버스 예매해줘',
#  '/DEP;안산/에서 /ARR;정안/로 가는 버스 예매하려하는데 표 있어?',
#  '/DEP;안성공도/에서 /ARR;서울경부/로 가는 버스 예약하려하는데 표 있어?',
#  '/DEP;안성한경/에서 /ARR;서울경부/로 가는 버스 예약하려하는데 표 있어?',
#  '/DEP;상봉/에서 /ARR;정안/로 가는 버스 예약하려 해',
#  '/DEP;용인유방/에서 /ARR;서울경부/로 가는 버스 예매하려 해',
#  '/DEP;광양/에서 /ARR;김해/로 가는 버스 예약할래',
#  '/DEP;화순/에서 /ARR;서울호남/로 가는 버스 예약해',
#  '/DEP;영천망정동/에서 /ARR;서울경부/로 가는 버스 예매해',
#  '/DEP;김제/에서 /ARR;정안/로 가는 버스 예매해줘',
#  '/DEP;순천종합/에서 /ARR;청사시외/로 가는 버스 예약해줘',
#  '/DEP;광양/에서 /ARR;당진/로 가는 버스 예약하려하는데 표 있어?',
#  '/DEP;화순/에서 /ARR;서울호남/로 가는 버스 예매할래',
#  '/DEP;오산/에서 /ARR;광명/로 가는 버스 예약하려하는데 표 있어?',
#  '/DEP;서부산/에서 /ARR;용인/로 가는 버스 예매하려 해',
#  '/DEP;안성공도/에서 /ARR;서울경부/로 가는 버스 예매해줘',
#  '/DEP;안성대림/에서 /ARR;홍대조치원/로 가는 버스 예매하려하는데 표 있어?',
#  '/DEP;평택대/에서 /ARR;홍대조치원/로 가는 버스 예매해',
#  '/DEP;영산포/에서 /ARR;정안/로 가는 버스 예약할래',
#  '/DEP;창원역/에서 /ARR;서울경부/로 가는 버스 예약해줘',
#  '/DEP;대전복합/에서 /ARR;상봉/로 가는 버스 예매하려 해',
#  '/DEP;세종청사/에서 /ARR;서울경부/로 가는 버스 예약할래',
#  '/DEP
에서 /ARR;서울/로 가는 버스 예매할래',
#  '/DEP;아산서부/에서 /ARR;서울경부/로 가는 버스 예약하려 해',
#  '/DEP;천안아산역/에서 /ARR;서울경부/로 가는 버스 예매할래',
#  '/DEP;인삼랜드/에서 /ARR;용인신갈/로 가는 버스 예약하려 해',
#  '/DEP;안성공도/에서 /ARR;홍대조치원/로 가는 버스 예약해',
#  '/DEP;대구동양/에서 /ARR;선산/로 가는 버스 예약할래',
#  '/DEP;조치원/에서 /ARR;서울경부/로 가는 버스 예매하려 해',
#  '/DEP;세종청사/에서 /ARR;홍대조치원/로 가는 버스 예매해줘',
#  '/DEP;정읍/에서 /ARR;정안/로 가는 버스 예약해줘',
#  '/DEP;춘천/에서 /ARR;대구중앙/로 가는 버스 예약해',
#  '/DEP;평택대/에서 /ARR;서울경부/로 가는 버스 예매해',
#  '/DEP;센트럴/에서 /ARR;녹동/로 가는 버스 예약해',
#  '/DEP;예천/에서 /ARR;서울경부/로 가는 버스 예약하려 해',
#  '/DEP;밀양/에서 /ARR;서울경부/로 가는 버스 예약해줘',
#  '/DEP;연무대/에서 /ARR;서울/로 가는 버스 예약하려하는데 표 있어?',
#  '/DEP;밀양/에서 /ARR;서울경부/로 가는 버스 예약하려 해',
#  '/DEP;용인유방/에서 /ARR;서울경부/로 가는 버스 예약해',
#  '/DEP;공주/에서 /ARR;서울경부/로 가는 버스 예약해줘',
#  '/DEP;대구한진/에서 /ARR;마산/로 가는 버스 예매할래',
#  '/DEP;예천/에서 /ARR;서울경부/로 가는 버스 예매해',
#  '/DEP;영암/에서 /ARR;서울/로 가는 버스 예약하려 해',
#  '/DEP;덕과/에서 /ARR;오산/로 가는 버스 예매해',
#  '/DEP;강릉/에서 /ARR;광명/로 가는 버스 예약해',
#  '/DEP;인천/에서 /ARR;전주공용/로 가는 버스 예매하려하는데 표 있어?',
#  '/DEP;예천/에서 /ARR;서울경부/로 가는 버스 예매해',
#  '/DEP;김해장유/에서 /ARR;선산/로 가는 버스 예매할래',
#  '/DEP;파주문산/에서 /ARR;선산/로 가는 버스 예매하려하는데 표 있어?',
#  '/DEP;김천/에서 /ARR;서울경부/로 가는 버스 예약하려 해',
#  '/DEP;서울경부/에서 /ARR;용인/로 가는 버스 예매해',
#  '/DEP;평택/에서 /ARR;홍대조치원/로 가는 버스 예약해',
#  '/DEP;천안/에서 /ARR;선산/로 가는 버스 예약하려 해',
#  '/DEP;선산/에서 /ARR;청주/로 가는 버스 예매해줘',
#  '/DEP;영암/에서 /ARR;서울/로 가는 버스 예매할래',
#  '/DEP;평택/에서 /ARR;홍대조치원/로 가는 버스 예약해줘',
#  '/DEP;순천종합/에서 /ARR;신갈시외/로 가는 버스 예약해',
#  '/DEP;화순/에서 /ARR;서울호남/로 가는 버스 예약할래',
#  '/DEP;전주/에서 /ARR;서울/로 가는 버스 예매하려 해',
#  '/ARR;서울경부/로 가는 버스 예매할래. /DEP;영천망정동/에서 출발할꺼야',
#  '/ARR;서울경부/로 가는 버스 예약해줘. /DEP;안성한경/에서 출발할꺼야',
#  '/ARR;안산/로 가는 버스 예약해. /DEP;대구한진/에서 출발할꺼야',
#  '/ARR;부산/로 가는 버스 예약하려하는데 표 있어?. /DEP;구리/에서 출발할꺼야',
#  '/ARR;서부산/로 가는 버스 예약할래. /DEP;용인/에서 출발할꺼야',
#  '/ARR;정안/로 가는 버스 예매해. /DEP;녹동/에서 출발할꺼야',
#  '/ARR;서울경부/로 가는 버스 예매해. /DEP;밀양/에서 출발할꺼야',
#  '/ARR;대구동양/로 가는 버스 예약하려 해. /DEP;경주/에서 출발할꺼야',
#  '/ARR;서울경부/로 가는 버스 예매할래. /DEP;홍대조치원/에서 출발할꺼야',
#  '/ARR;서울호남/로 가는 버스 예약해줘. /DEP;능주/에서 출발할꺼야',
#  '/ARR;정안/로 가는 버스 예매할래. /DEP;담양/에서 출발할꺼야',
#  '/ARR;순천종합/로 가는 버스 예매해줘. /DEP;신갈시외/에서 출발할꺼야',
#  '/ARR;부산/로 가는 버스 예약해. /DEP;여수/에서 출발할꺼야',
#  '/ARR;서울경부/로 가는 버스 예매해줘. /DEP;황간/에서 출발할꺼야',
#  '/ARR;홍대조치원/로 가는 버스 예약해. /DEP;강릉/에서 출발할꺼야',
#  '/ARR;여수/로 가는 버스 예약할래. /DEP;인천공항/에서 출발할꺼야',
#  '/ARR;익산/로 가는 버스 예매하려하는데 표 있어?. /DEP;안산/에서 출발할꺼야',
#  '/ARR;서울/로 가는 버스 예약할래. /DEP;김제/에서 출발할꺼야',
#  '/ARR;서울경부/로 가는 버스 예매하려 해. /DEP;영천망정동/에서 출발할꺼야',
#  '/ARR;서울경부/로 가는 버스 예매해. /DEP;영주/에서 출발할꺼야',
#  '/ARR;덕과/로 가는 버스 예약할래. /DEP;서수원/에서 출발할꺼야',
#  '/ARR;서울경부/로 가는 버스 예매해줘. /DEP;밀양/에서 출발할꺼야',
#  '/ARR;전주공용/로 가는 버스 예약하려하는데 표 있어?. /DEP;대구동양/에서 출발할꺼야',
#  '/ARR;목포/로 가는 버스 예매할래. /DEP;구미/에서 출발할꺼야',
#  '/ARR;정안/로 가는 버스 예약하려 해. /DEP;담양/에서 출발할꺼야',
#  '/ARR;선산/로 가는 버스 예매할래. /DEP;김해/에서 출발할꺼야',
#  '/ARR;서울남부/로 가는 버스 예약해. /DEP;통영/에서 출발할꺼야',
#  '/ARR;광주/로 가는 버스 예약하려하는데 표 있어?. /DEP;시흥/에서 출발할꺼야',
#  '/ARR;서울경부/로 가는 버스 예매해. /DEP;밀양/에서 출발할꺼야',
#  '/ARR;정안/로 가는 버스 예약할래. /DEP;벌교/에서 출발할꺼야',
#  '/ARR;정안/로 가는 버스 예약해. /DEP;김제/에서 출발할꺼야',
#  '/ARR;서울경부/로 가는 버스 예매하려하는데 표 있어?. /DEP;영천망정동/에서 출발할꺼야',
#  '/ARR;정안/로 가는 버스 예약하려하는데 표 있어?. /DEP;안산/에서 출발할꺼야',
#  '/ARR;서울경부/로 가는 버스 예매해. /DEP;금산/에서 출발할꺼야',
#  '/ARR;순천종합/로 가는 버스 예매하려 해. /DEP;신갈시외/에서 출발할꺼야',
#  '/ARR;정안/로 가는 버스 예매해줘. /DEP;상봉/에서 출발할꺼야',
#  '/ARR;서울/로 가는 버스 예매하려하는데 표 있어?. /DEP;회진/에서 출발할꺼야',
#  '/ARR;서울/로 가는 버스 예매하려 해. /DEP;보성/에서 출발할꺼야',
#  '/ARR;의정부/로 가는 버스 예약할래. /DEP;광주/에서 출발할꺼야',
#  '/ARR;횡성/로 가는 버스 예약해. /DEP;강릉/에서 출발할꺼야',
#  '/ARR;정안/로 가는 버스 예약하려하는데 표 있어?. /DEP;담양/에서 출발할꺼야',
#  '/ARR;서울호남/로 가는 버스 예매하려하는데 표 있어?. /DEP;능주/에서 출발할꺼야',
#  '/ARR;홍대조치원/로 가는 버스 예약해. /DEP;안성공도/에서 출발할꺼야',
#  '/ARR;서울경부/로 가는 버스 예약해. /DEP;이천/에서 출발할꺼야',
#  '/ARR;광주/로 가는 버스 예약해. /DEP;안산/에서 출발할꺼야',
#  '/ARR;서울경부/로 가는 버스 예매해. /DEP;조치원/에서 출발할꺼야',
#  '/ARR;서울/로 가는 버스 예매하려 해. /DEP;문장/에서 출발할꺼야',
#  '/ARR;정안/로 가는 버스 예매하려 해. /DEP;보성/에서 출발할꺼야',
#  '/ARR;용인신갈/로 가는 버스 예약하려하는데 표 있어?. /DEP;광주/에서 출발할꺼야',
#  '/ARR;서울경부/로 가는 버스 예매해. /DEP;안성/에서 출발할꺼야',
#  '/ARR;정안/로 가는 버스 예매하려하는데 표 있어?. /DEP;정읍/에서 출발할꺼야',
#  '/ARR;홍대조치원/로 가는 버스 예약해. /DEP;안성공도/에서 출발할꺼야',
#  '/ARR;대전복합/로 가는 버스 예약하려하는데 표 있어?. /DEP;내서/에서 출발할꺼야',
#  '/ARR;서울경부/로 가는 버스 예약하려 해. /DEP;밀양/에서 출발할꺼야',
#  '/ARR;서울/로 가는 버스 예매하려하는데 표 있어?. /DEP;녹동/에서 출발할꺼야',
#  '/ARR;서울/로 가는 버스 예매하려 해. /DEP;함평/에서 출발할꺼야',
#  '/ARR;선산/로 가는 버스 예매해줘. /DEP;창원역/에서 출발할꺼야',
#  '/ARR;정안/로 가는 버스 예매할래. /DEP;해남/에서 출발할꺼야',
#  '/ARR;홍대조치원/로 가는 버스 예약해줘. /DEP;평택대/에서 출발할꺼야',
#  '/ARR;서울/로 가는 버스 예매해. /DEP;연무대/에서 출발할꺼야',
#  '/ARR;섬진강/로 가는 버스 예약해. /DEP;서부산/에서 출발할꺼야',
#  '/ARR;횡성/로 가는 버스 예약해줘. /DEP;동해/에서 출발할꺼야',
#  '/ARR;서울/로 가는 버스 예약하려 해. /DEP;김제/에서 출발할꺼야',
#  '/ARR;청주/로 가는 버스 예약하려하는데 표 있어?. /DEP;상봉/에서 출발할꺼야',
#  '/ARR;서울/로 가는 버스 예매하려하는데 표 있어?. /DEP;고흥/에서 출발할꺼야',
#  '/ARR;정안/로 가는 버스 예매해줘. /DEP;벌교/에서 출발할꺼야',
#  '/ARR;서수원/로 가는 버스 예매하려 해. /DEP;오산/에서 출발할꺼야',
#  '/ARR;광주/로 가는 버스 예매하려하는데 표 있어?. /DEP;춘천/에서 출발할꺼야',
#  '/ARR;인천/로 가는 버스 예약하려 해. /DEP;속초/에서 출발할꺼야',
#  '/ARR;서울경부/로 가는 버스 예매해. /DEP;세종연구단지/에서 출발할꺼야',
#  '/ARR;서울/로 가는 버스 예약해. /DEP;함평/에서 출발할꺼야',
#  '/ARR;강릉/로 가는 버스 예약하려 해. /DEP;파주문산/에서 출발할꺼야',
#  '/ARR;서울경부/로 가는 버스 예약할래. /DEP;안성대림/에서 출발할꺼야',
#  '/ARR;안동/로 가는 버스 예약할래. /DEP;대구중앙/에서 출발할꺼야',
#  '/ARR;광주/로 가는 버스 예약할래. /DEP;경주/에서 출발할꺼야',
#  '/ARR;홍대조치원/로 가는 버스 예매해. /DEP;황간/에서 출발할꺼야',
#  '/ARR;서울경부/로 가는 버스 예약해. /DEP;영천망정동/에서 출발할꺼야',
#  '/ARR;서울/로 가는 버스 예매할래. /DEP;녹동/에서 출발할꺼야',
#  '/ARR;홍대조치원/로 가는 버스 예약하려 해. /DEP;이천/에서 출발할꺼야',
#  '/ARR;홍대조치원/로 가는 버스 예매할래. /DEP;황간/에서 출발할꺼야',
#  '/ARR;정안/로 가는 버스 예약해줘. /DEP;고흥/에서 출발할꺼야',
#  '/ARR;홍대조치원/로 가는 버스 예매하려 해. /DEP;양양/에서 출발할꺼야',
#  '/ARR;홍대조치원/로 가는 버스 예약할래. /DEP;세종시/에서 출발할꺼야',
#  '/ARR;부산/로 가는 버스 예매할래. /DEP;여천/에서 출발할꺼야',
#  '/ARR;파주운정/로 가는 버스 예약해. /DEP;마산/에서 출발할꺼야',
#  '/ARR;홍대조치원/로 가는 버스 예매해줘. /DEP;안성회관/에서 출발할꺼야',
#  '/ARR;선산/로 가는 버스 예매해줘. /DEP;김해/에서 출발할꺼야',
#  '/ARR;순천종합/로 가는 버스 예매하려 해. /DEP;서부산/에서 출발할꺼야',
#  '/ARR;서울경부/로 가는 버스 예매해. /DEP;영천/에서 출발할꺼야',
#  '/ARR;홍대조치원/로 가는 버스 예약하려하는데 표 있어?. /DEP;용인유방/에서 출발할꺼야',
#  '/ARR;홍대조치원/로 가는 버스 예약할래. /DEP;용인유방/에서 출발할꺼야',
#  '/ARR;홍대조치원/로 가는 버스 예약하려 해. /DEP;원주/에서 출발할꺼야',
#  '/ARR;순천종합/로 가는 버스 예약할래. /DEP;신갈시외/에서 출발할꺼야',
#  '/ARR;서울/로 가는 버스 예매해. /DEP;녹동/에서 출발할꺼야',
#  '/ARR;서울/로 가는 버스 예약하려 해. /DEP;벌교/에서 출발할꺼야',
#  '/ARR;서울경부/로 가는 버스 예매하려 해. /DEP;창원/에서 출발할꺼야',
#  '/ARR;서울/로 가는 버스 예매할래. /DEP;순창/에서 출발할꺼야',
#  '/ARR;조치원/로 가는 버스 예매할래. /DEP;서울경부/에서 출발할꺼야',
#  '/ARR;부산/로 가는 버스 예매하려하는데 표 있어?. /DEP;구리/에서 출발할꺼야',
#  '/ARR;서울경부/로 가는 버스 예약하려하는데 표 있어?. /DEP;상주/에서 출발할꺼야',
#  '/ARR;김해/로 가는 버스 예매해줘. /DEP;순천종합/에서 출발할꺼야',
#  '/ARR;서울/로 가는 버스 예약할래. /DEP;벌교/에서 출발할꺼야',
#  '/ARR;홍대조치원/로 가는 버스 예약할래. /DEP;점촌/에서 출발할꺼야',
#  '/ARR;익산/로 가는 버스 예약하려 해. /DEP;안산/에서 출발할꺼야',
#  '/ARR;수원/로 가는 버스 예매할래. /DEP;여천/에서 출발할꺼야',
#  '/ARR;안동/로 가는 버스 예매해줘. /DEP;대구중앙/에서 출발할꺼야',
#  '/ARR;서울경부/로 가는 버스 예약해줘. /DEP;예천/에서 출발할꺼야',
#  '/ARR;광명/로 가는 버스 예약해. /DEP;호남제일문/에서 출발할꺼야',
#  '/ARR;군산/로 가는 버스 예약하려하는데 표 있어?. /DEP;여천/에서 출발할꺼야',
#  '/ARR;대구한진/로 가는 버스 예매할래. /DEP;성남/에서 출발할꺼야',
#  '/ARR;서울/로 가는 버스 예매해. /DEP;고흥/에서 출발할꺼야',
#  '/ARR;정안/로 가는 버스 예약하려하는데 표 있어?. /DEP;녹동/에서 출발할꺼야',
#  '/ARR;파주문산/로 가는 버스 예약하려하는데 표 있어?. /DEP;대전청사/에서 출발할꺼야',
#  '/ARR;홍대조치원/로 가는 버스 예매하려 해. /DEP;세종청사/에서 출발할꺼야',
#  '/ARR;충주/로 가는 버스 예약해줘. /DEP;고양백석/에서 출발할꺼야',
#  '/ARR;부산/로 가는 버스 예약할래. /DEP;구리/에서 출발할꺼야',
#  '/ARR;오산/로 가는 버스 예매하려하는데 표 있어?. /DEP;내서/에서 출발할꺼야',
#  '/ARR;서울경부/로 가는 버스 예매할래. /DEP;예천/에서 출발할꺼야',
#  '/ARR;정안/로 가는 버스 예매할래. /DEP;고흥/에서 출발할꺼야',
#  '/ARR;서울경부/로 가는 버스 예매하려하는데 표 있어?. /DEP;김천/에서 출발할꺼야',
#  '/ARR;서울/로 가는 버스 예약하려 해. /DEP;장성/에서 출발할꺼야',
#  '/ARR;대구중앙/로 가는 버스 예약하려하는데 표 있어?. /DEP;진주/에서 출발할꺼야',
#  '/ARR;홍대조치원/로 가는 버스 예약해줘. /DEP;평택대/에서 출발할꺼야',
#  '/ARR;정안/로 가는 버스 예약해. /DEP;안산/에서 출발할꺼야',
#  '/ARR;영산포/로 가는 버스 예약해줘. /DEP;정안/에서 출발할꺼야',
#  '/ARR;서울/로 가는 버스 예매하려하는데 표 있어?. /DEP;벌교/에서 출발할꺼야',
#  '/ARR;안산/로 가는 버스 예약하려 해. /DEP;익산/에서 출발할꺼야',
#  '/ARR;인천/로 가는 버스 예약해. /DEP;여천/에서 출발할꺼야',
#  '/ARR;홍대조치원/로 가는 버스 예매할래. /DEP;이천/에서 출발할꺼야',
#  '/ARR;서울경부/로 가는 버스 예약해줘. /DEP;밀양/에서 출발할꺼야',
#  '/ARR;통영/로 가는 버스 예약해줘. /DEP;인삼랜드/에서 출발할꺼야',
#  '/ARR;서울경부/로 가는 버스 예매해. /DEP;영주/에서 출발할꺼야',
#  '/ARR;마산/로 가는 버스 예약하려 해. /DEP;파주운정/에서 출발할꺼야',
#  '/ARR;홍대조치원/로 가는 버스 예약해줘. /DEP;대구중앙/에서 출발할꺼야',
#  '/ARR;부산/로 가는 버스 예매하려 해. /DEP;구리/에서 출발할꺼야',
#  '/ARR;광명/로 가는 버스 예매하려하는데 표 있어?. /DEP;전주/에서 출발할꺼야',
#  '/ARR;서울경부/로 가는 버스 예약해. /DEP;황간/에서 출발할꺼야',
#  '/ARR;서울/로 가는 버스 예약해줘. /DEP;논산/에서 출발할꺼야',
#  '/ARR;파주문산/로 가는 버스 예약할래. /DEP;선산/에서 출발할꺼야',
#  '/ARR;정안/로 가는 버스 예약하려하는데 표 있어?. /DEP;삼호/에서 출발할꺼야',
#  '/ARR;서울경부/로 가는 버스 예약해줘. /DEP;이천/에서 출발할꺼야',
#  '/ARR;홍대조치원/로 가는 버스 예매해줘. /DEP;안성중대/에서 출발할꺼야',
#  '/ARR;서울/로 가는 버스 예약하려하는데 표 있어?. /DEP;여천/에서 출발할꺼야',
#  '/ARR;파주문산/로 가는 버스 예매할래. /DEP;대전청사/에서 출발할꺼야',
#  '/ARR;서울경부/로 가는 버스 예매하려하는데 표 있어?. /DEP;밀양/에서 출발할꺼야',
#  '/ARR;부산/로 가는 버스 예약할래. /DEP;성남/에서 출발할꺼야',
#  '/ARR;서부산/로 가는 버스 예약해. /DEP;서울경부/에서 출발할꺼야',
#  '/ARR;홍대조치원/로 가는 버스 예매해줘. /DEP;안성대림/에서 출발할꺼야',
#  '/ARR;전주/로 가는 버스 예매할래. /DEP;고양화정/에서 출발할꺼야',
#  '/ARR;서울/로 가는 버스 예매하려 해. /DEP;남원/에서 출발할꺼야',
#  '/ARR;서울호남/로 가는 버스 예매해줘. /DEP;능주/에서 출발할꺼야',
#  '/ARR;홍대조치원/로 가는 버스 예약하려하는데 표 있어?. /DEP;양양/에서 출발할꺼야',
#  '/ARR;광명/로 가는 버스 예매해줘. /DEP;속초/에서 출발할꺼야',
#  '/ARR;강릉/로 가는 버스 예약할래. /DEP;고양화정/에서 출발할꺼야',
#  '/ARR;진주/로 가는 버스 예매하려 해. /DEP;용인/에서 출발할꺼야',
#  '/ARR;서울/로 가는 버스 예매하려하는데 표 있어?. /DEP;함평/에서 출발할꺼야',
#  '/ARR;서울/로 가는 버스 예매하려하는데 표 있어?. /DEP;노력항/에서 출발할꺼야',
#  '/ARR;홍대조치원/로 가는 버스 예매해줘. /DEP;울산신복/에서 출발할꺼야',
#  '/ARR;성남/로 가는 버스 예약할래. /DEP;마산/에서 출발할꺼야',
#  '/ARR;수원/로 가는 버스 예약하려하는데 표 있어?. /DEP;목포/에서 출발할꺼야',
#  '/ARR;정안/로 가는 버스 예매하려하는데 표 있어?. /DEP;벌교/에서 출발할꺼야',
#  '/ARR;파주문산/로 가는 버스 예매해줘. /DEP;창원/에서 출발할꺼야',
#  '/ARR;파주운정/로 가는 버스 예약하려 해. /DEP;대전청사/에서 출발할꺼야',
#  '/ARR;서울경부/로 가는 버스 예매해줘. /DEP;예천/에서 출발할꺼야',
#  '/ARR;인천/로 가는 버스 예매하려하는데 표 있어?. /DEP;덕과/에서 출발할꺼야',
#  '/ARR;통영/로 가는 버스 예매해. /DEP;성남/에서 출발할꺼야',
#  '/ARR;서울/로 가는 버스 예약하려 해. /DEP;함평/에서 출발할꺼야',
#  '/ARR;서울경부/로 가는 버스 예매할래. /DEP;김해장유/에서 출발할꺼야',
#  '/ARR;서부산/로 가는 버스 예약해줘. /DEP;성남/에서 출발할꺼야',
#  '/ARR;서울/로 가는 버스 예약해. /DEP;노력항/에서 출발할꺼야',
#  '/ARR;홍대조치원/로 가는 버스 예매할래. /DEP;여주/에서 출발할꺼야',
#  '/ARR;홍대조치원/로 가는 버스 예매해줘. /DEP;금산/에서 출발할꺼야',
#  '/ARR;홍대조치원/로 가는 버스 예매하려하는데 표 있어?. /DEP;황간/에서 출발할꺼야',
#  '/ARR;여천/로 가는 버스 예약하려하는데 표 있어?. /DEP;군산/에서 출발할꺼야',
#  '/ARR;서울/로 가는 버스 예매할래. /DEP;장성/에서 출발할꺼야',
#  '/ARR;서울경부/로 가는 버스 예매할래. /DEP;천안아산역/에서 출발할꺼야',
#  '/ARR;홍대조치원/로 가는 버스 예매해. /DEP;천안아산역/에서 출발할꺼야',
#  '/ARR;선산/로 가는 버스 예약할래. /DEP;창원역/에서 출발할꺼야',
#  '/ARR;정안/로 가는 버스 예약할래. /DEP;호남제일문/에서 출발할꺼야',
#  '/ARR;창원/로 가는 버스 예약하려하는데 표 있어?. /DEP;파주문산/에서 출발할꺼야',
#  '/ARR;홍대조치원/로 가는 버스 예매해. /DEP;황간/에서 출발할꺼야',
#  '/ARR;광주/로 가는 버스 예매하려하는데 표 있어?. /DEP;시흥/에서 출발할꺼야',
#  '/ARR;홍대조치원/로 가는 버스 예약하려 해. /DEP;안성/에서 출발할꺼야',
#  '/ARR;서울경부/로 가는 버스 예약해. /DEP;공주/에서 출발할꺼야',
#  '/ARR;홍대조치원/로 가는 버스 예약해줘. /DEP;김해/에서 출발할꺼야',
#  '/ARR;서울경부/로 가는 버스 예매하려하는데 표 있어?. /DEP;아산서부/에서 출발할꺼야',
#  '/ARR;전주/로 가는 버스 예매하려하는데 표 있어?. /DEP;상봉/에서 출발할꺼야',
#  '/ARR;서울경부/로 가는 버스 예약해줘. /DEP;조치원/에서 출발할꺼야',
#  '/ARR;광명/로 가는 버스 예매해줘. /DEP;강릉/에서 출발할꺼야',
#  '/ARR;동광양/로 가는 버스 예약할래. /DEP;통영/에서 출발할꺼야',
#  '/ARR;인천/로 가는 버스 예매해. /DEP;익산팔봉/에서 출발할꺼야',
#  '/ARR;서울/로 가는 버스 예약해줘. /DEP;회진/에서 출발할꺼야',
#  '/ARR;서울경부/로 가는 버스 예약해줘. /DEP;고대세종/에서 출발할꺼야',
#  '/ARR;홍대조치원/로 가는 버스 예매할래. /DEP;대구동양/에서 출발할꺼야',
#  '/ARR;홍대조치원/로 가는 버스 예매하려하는데 표 있어?. /DEP;용인유방/에서 출발할꺼야',
#  '/ARR;서울/로 가는 버스 예약해. /DEP;연무대/에서 출발할꺼야',
#  '/ARR;서울경부/로 가는 버스 예약하려 해. /DEP;밀양/에서 출발할꺼야',
#  '/ARR;정안/로 가는 버스 예약하려하는데 표 있어?. /DEP;삼호/에서 출발할꺼야',
#  '/ARR;서울경부/로 가는 버스 예약하려 해. /DEP;김천/에서 출발할꺼야',
#  '/ARR;서울경부/로 가는 버스 예약하려 해. /DEP;용인/에서 출발할꺼야',
#  ...]

# %%
reject=['','아니 ','음.. ','음.. 아니 ','아니야 ']
change=['로','로 바꿀게','로 수정해줘','로 바꿔 줘','로 바꿔 주세요','로 수정할게']
dep_change=['에 출발','에 출발하는 걸','출발']
arr_change=['에 도착','도착']

# %%
###출발 

#ex.1월 1일 낮 12시 (출발)로 바꿀게, 내일로 바꿀게
sec_bus_list_1=[]
for i in range(1000):
  sec_bus_list_1.append(random.choice(reject)+random.choice(['',get_date_with_day(),get_date_not_exact_int(),get_date(random.choice([0,1]))])+random.choice([get_dtime_hour(),get_dtime_full_hour()])+random.choice(dep_change)+random.choice(change))

#ex.아니 지금
sec_bus_list_2=[]
for i in range(50):
  sec_bus_list_2.append(random.choice(reject)+get_date(2))

#ex.아니 이번주 월요일 낮 12시 30분으로 바꿀게
sec_bus_list_3=[]
for i in range(1000):
  sec_bus_list_3.append(random.choice(reject)+random.choice(['',get_date_with_day(),get_date_not_exact_int(),get_date(random.choice([0,1]))])+' '+random.choice([get_dtime_hour_exact_min(),get_dtime_full_hour_exact_min()])+'으'+random.choice(change))

#ex.아니 이번주 월요일 낮 12시 30분 출발로 바꿀게
sec_bus_list_4=[]
for i in range(1000):
  sec_bus_list_4.append(random.choice(reject)+random.choice(['',get_date_with_day(),get_date_not_exact_int(),get_date(random.choice([0,1]))])+' '+random.choice([get_dtime_hour_exact_min(),get_dtime_full_hour_exact_min()])+random.choice(dep_change)+random.choice(change))

#ex.아니 12시간 뒤 (출발)로 바꿀게
sec_bus_list_5=[]
for i in range(100):
  sec_bus_list_5.append(random.choice(reject)+random.choice([get_dtime_hour_later(),get_dtime_min_later()])+random.choice(dep_change)+random.choice(change))


### 도착

#ex.아니 1월 1일 낮 12시 도착으로 바꿀게
sec_bus_list_6=[]
for i in range(1000):
  sec_bus_list_6.append(random.choice(reject)+random.choice(['',get_date_with_day(),get_date_not_exact_int(),get_date(random.choice([0,1]))])+random.choice(['',get_atime_hour(),get_atime_hour_exact_min(),get_atime_hour_later(),get_atime_full_hour(),get_atime_full_hour_exact_min()])+random.choice(arr_change)+'으'+random.choice(change))

#ex.아니 1월 1일 낮 12시에 도착하는걸로 바꿀게
sec_bus_list_7=[]
for i in range(500):
  sec_bus_list_7.append(random.choice(reject)+random.choice(['',get_date_with_day(),get_date_not_exact_int(),get_date(random.choice([0,1]))])+random.choice(['',get_atime_hour(),get_atime_hour_exact_min(),get_atime_hour_later(),get_atime_full_hour(),get_atime_full_hour_exact_min()])+'에 도착하는 걸'+random.choice(change))



bus_list_change=sec_bus_list_1+sec_bus_list_2+sec_bus_list_3+sec_bus_list_4+sec_bus_list_5+sec_bus_list_6+sec_bus_list_7

bus_list_change
# Out:
# ['/DATE;익일//DEP_TIME;오전 3시/에 출발로 바꿔 주세요',
#  '아니야 /DATE;다다음주 토요일//DEP_TIME;낮 4시/에 출발하는 걸로 바꿔 주세요',
#  '아니 /DEP_TIME;18시/출발로 바꿀게',
#  '음.. /DEP_TIME;저녁 7시/에 출발하는 걸로 수정할게',
#  '음.. 아니 /DATE;8월 8일//DEP_TIME;아침 9시/에 출발하는 걸로 바꿀게',
#  '/DEP_TIME;오후 2시/출발로',
#  '/DEP_TIME;4시/에 출발하는 걸로 수정해줘',
#  '아니 /DATE;6월 30일//DEP_TIME;17시/에 출발로 바꿔 줘',
#  '아니야 /DATE;2일 뒤//DEP_TIME;오전 9시/에 출발로 수정해줘',
#  '아니 /DATE;익일//DEP_TIME;낮 9시/출발로 수정해줘',
#  '음.. 아니 /DEP_TIME;16시/에 출발하는 걸로 수정해줘',
#  '아니 /DATE;이번주 목요일//DEP_TIME;18시/에 출발하는 걸로 바꿔 줘',
#  '음.. /DEP_TIME;저녁 10시/에 출발로 수정해줘',
#  '음.. /DATE;12월 29일//DEP_TIME;8시/출발로',
#  '아니 /DATE;1일 뒤//DEP_TIME;18시/에 출발하는 걸로',
#  '/DATE;10월 6일//DEP_TIME;9시/에 출발하는 걸로',
#  '음.. /DATE;보름//DEP_TIME;오후 6시/에 출발하는 걸로 수정해줘',
#  '아니 /DATE;12월 9일//DEP_TIME;저녁 5시/에 출발로 수정해줘',
#  '음.. /DATE;4일 뒤//DEP_TIME;14시/에 출발하는 걸로 수정할게',
#  '음.. 아니 /DATE;2주 뒤//DEP_TIME;오전 11시/에 출발로 바꿀게',
#  '음.. 아니 /DATE;이번주 수요일//DEP_TIME;저녁 5시/에 출발로 바꿔 주세요',
#  '아니 /DATE;다다음주 목요일//DEP_TIME;9시/에 출발로 바꿔 줘',
#  '아니 /DEP_TIME;12시/출발로 수정할게',
#  '아니야 /DATE;3월 24일//DEP_TIME;저녁 1시/출발로 바꿔 줘',
#  '음.. 아니 /DATE;다음주 월요일//DEP_TIME;오전 2시/에 출발로 바꿔 주세요',
#  '음.. /DATE;이번주 목요일//DEP_TIME;2시/출발로 바꿔 주세요',
#  '아니 /DATE;1주 뒤//DEP_TIME;19시/에 출발하는 걸로 바꿀게',
#  '/DEP_TIME;낮 11시/출발로 바꿔 줘',
#  '음.. 아니 /DEP_TIME;9시/에 출발로 바꿔 주세요',
#  '아니 /DEP_TIME;1시/에 출발하는 걸로 수정해줘',
#  '음.. /DATE;8월 13일//DEP_TIME;14시/에 출발하는 걸로 바꿀게',
#  '음.. 아니 /DATE;이번주 월요일//DEP_TIME;오후 9시/출발로 바꿔 줘',
#  '/DEP_TIME;12시/에 출발로 바꿔 줘',
#  '음.. /DATE;4일 뒤//DEP_TIME;22시/에 출발로 수정해줘',
#  '음.. /DATE;다다음주 수요일//DEP_TIME;새벽 6시/출발로 바꿀게',
#  '/DATE;다음주 토요일//DEP_TIME;7시/에 출발로 수정해줘',
#  '아니 /DATE;다음주 화요일//DEP_TIME;아침 7시/에 출발로 수정해줘',
#  '아니 /DEP_TIME;19시/에 출발하는 걸로 바꿔 줘',
#  '음.. /DATE;2일 뒤//DEP_TIME;21시/에 출발하는 걸로 수정해줘',
#  '음.. /DATE;다음주 월요일//DEP_TIME;14시/에 출발하는 걸로',
#  '음.. 아니 /DATE;2주일 뒤//DEP_TIME;8시/에 출발로 수정할게',
#  '아니야 /DATE;다다음주 월요일//DEP_TIME;밤 1시/에 출발하는 걸로 바꿔 주세요',
#  '아니 /DATE;내일 모레//DEP_TIME;16시/에 출발로',
#  '아니 /DATE;2주일 뒤//DEP_TIME;오후 3시/에 출발하는 걸로 수정할게',
#  '음.. /DEP_TIME;13시/출발로 수정할게',
#  '음.. /DATE;명일//DEP_TIME;9시/에 출발하는 걸로 바꿀게',
#  '음.. /DATE;4일 뒤//DEP_TIME;새벽 5시/출발로 바꿀게',
#  '음.. /DATE;오늘//DEP_TIME;20시/에 출발로 수정할게',
#  '/DEP_TIME;21시/에 출발로 바꿀게',
#  '/DATE;3일 뒤//DEP_TIME;아침 6시/에 출발하는 걸로 수정해줘',
#  '음.. /DATE;내일//DEP_TIME;14시/에 출발로 수정해줘',
#  '음.. 아니 /DATE;다다음주 일요일//DEP_TIME;5시/에 출발하는 걸로 수정해줘',
#  '음.. /DEP_TIME;9시/출발로 수정해줘',
#  '/DEP_TIME;4시/출발로 바꿀게',
#  '아니야 /DATE;다음주 일요일//DEP_TIME;새벽 3시/에 출발로 바꿀게',
#  '음.. /DATE;11월 7일//DEP_TIME;오후 10시/출발로',
#  '아니 /DATE;이번주 화요일//DEP_TIME;오후 4시/출발로 바꿔 주세요',
#  '아니야 /DATE;다다음주 월요일//DEP_TIME;저녁 4시/에 출발하는 걸로',
#  '음.. 아니 /DATE;이번주 목요일//DEP_TIME;22시/에 출발하는 걸로 바꿔 줘',
#  '아니야 /DATE;4월 6일//DEP_TIME;오전 8시/출발로 수정해줘',
#  '/DATE;이번주 목요일//DEP_TIME;오후 1시/에 출발하는 걸로 바꿔 줘',
#  '아니 /DATE;다음주 화요일//DEP_TIME;아침 11시/에 출발하는 걸로 수정해줘',
#  '/DEP_TIME;저녁 8시/에 출발로',
#  '음.. 아니 /DATE;다음주 일요일//DEP_TIME;19시/에 출발하는 걸로 수정할게',
#  '/DEP_TIME;19시/에 출발하는 걸로 수정할게',
#  '음.. 아니 /DATE;내일//DEP_TIME;아침 4시/에 출발로 바꿀게',
#  '아니야 /DATE;4주일 뒤//DEP_TIME;0시/출발로 바꿀게',
#  '/DATE;5일 뒤//DEP_TIME;10시/에 출발하는 걸로 수정할게',
#  '아니 /DATE;다다음주 금요일//DEP_TIME;아침 9시/에 출발로 바꿀게',
#  '음.. /DEP_TIME;1시/에 출발로 바꿔 주세요',
#  '아니야 /DATE;6월 17일//DEP_TIME;오후 4시/에 출발하는 걸로',
#  '아니 /DEP_TIME;4시/출발로 수정해줘',
#  '/DEP_TIME;오후 5시/에 출발하는 걸로 수정해줘',
#  '음.. 아니 /DATE;3일 뒤//DEP_TIME;낮 7시/에 출발하는 걸로 수정할게',
#  '/DATE;5월 23일//DEP_TIME;새벽 8시/출발로 바꿀게',
#  '음.. /DEP_TIME;저녁 8시/출발로 수정할게',
#  '음.. /DATE;4일 뒤//DEP_TIME;12시/에 출발로 수정해줘',
#  '음.. /DATE;오늘//DEP_TIME;0시/에 출발로 바꿔 주세요',
#  '음.. 아니 /DATE;5월 21일//DEP_TIME;15시/출발로 바꿔 줘',
#  '/DATE;2주일 뒤//DEP_TIME;밤 4시/출발로 바꿔 주세요',
#  '아니야 /DATE;금일//DEP_TIME;아침 1시/출발로 수정할게',
#  '음.. /DATE;2주 뒤//DEP_TIME;14시/에 출발하는 걸로',
#  '/DATE;7월 9일//DEP_TIME;10시/출발로 바꿔 주세요',
#  '/DATE;5일 뒤//DEP_TIME;12시/에 출발로 바꿀게',
#  '음.. /DATE;명일//DEP_TIME;5시/에 출발하는 걸로 수정해줘',
#  '음.. /DEP_TIME;아침 2시/에 출발하는 걸로',
#  '음.. 아니 /DATE;8월 23일//DEP_TIME;낮 10시/에 출발로',
#  '/DATE;5월 11일//DEP_TIME;저녁 3시/출발로 수정할게',
#  '음.. /DATE;다다음주 토요일//DEP_TIME;5시/에 출발로',
#  '아니야 /DEP_TIME;오전 8시/에 출발하는 걸로 바꿔 줘',
#  '아니 /DATE;이번주 금요일//DEP_TIME;새벽 5시/에 출발로 바꿀게',
#  '음.. /DEP_TIME;9시/출발로 바꿔 줘',
#  '아니 /DEP_TIME;저녁 3시/에 출발로 바꿔 주세요',
#  '음.. 아니 /DATE;이번주 일요일//DEP_TIME;오후 6시/에 출발로',
#  '아니 /DATE;1주일 뒤//DEP_TIME;낮 4시/에 출발로',
#  '아니 /DATE;내일 모레//DEP_TIME;저녁 3시/에 출발로 수정해줘',
#  '/DATE;오늘//DEP_TIME;17시/출발로',
#  '/DEP_TIME;13시/에 출발로 바꿔 줘',
#  '음.. 아니 /DATE;다다음주 월요일//DEP_TIME;6시/출발로 수정할게',
#  '아니야 /DATE;8월 5일//DEP_TIME;10시/에 출발로',
#  '아니 /DEP_TIME;6시/에 출발로 바꿀게',
#  '음.. /DATE;3주일 뒤//DEP_TIME;오전 4시/에 출발하는 걸로 수정해줘',
#  '음.. 아니 /DATE;이번주 금요일//DEP_TIME;낮 10시/출발로 바꿀게',
#  '아니 /DEP_TIME;아침 5시/에 출발하는 걸로',
#  '음.. /DATE;4주일 뒤//DEP_TIME;23시/에 출발로 바꿔 줘',
#  '음.. 아니 /DEP_TIME;6시/출발로 바꿔 줘',
#  '아니야 /DEP_TIME;아침 2시/에 출발하는 걸로 바꿔 줘',
#  '/DATE;금일//DEP_TIME;오전 7시/에 출발로 수정할게',
#  '아니야 /DATE;5주일 뒤//DEP_TIME;아침 4시/에 출발하는 걸로 바꿀게',
#  '/DATE;오늘//DEP_TIME;밤 6시/에 출발로 수정해줘',
#  '음.. 아니 /DATE;4일 뒤//DEP_TIME;11시/출발로 수정해줘',
#  '음.. /DATE;2일 뒤//DEP_TIME;아침 4시/에 출발하는 걸로',
#  '음.. 아니 /DATE;다음주 금요일//DEP_TIME;17시/에 출발하는 걸로 수정해줘',
#  '아니 /DATE;내일//DEP_TIME;오후 8시/에 출발하는 걸로 바꿀게',
#  '아니야 /DATE;명일//DEP_TIME;16시/출발로 바꿀게',
#  '아니야 /DEP_TIME;5시/에 출발로 바꿔 줘',
#  '음.. 아니 /DATE;2월 7일//DEP_TIME;5시/출발로',
#  '아니야 /DATE;이번주 화요일//DEP_TIME;낮 1시/출발로 수정할게',
#  '음.. 아니 /DATE;다다음주 수요일//DEP_TIME;저녁 1시/에 출발하는 걸로 수정할게',
#  '아니 /DEP_TIME;저녁 2시/출발로 수정해줘',
#  '아니 /DEP_TIME;17시/출발로 수정할게',
#  '아니야 /DATE;1일 뒤//DEP_TIME;11시/에 출발로',
#  '음.. 아니 /DATE;다다음주 토요일//DEP_TIME;0시/출발로',
#  '음.. 아니 /DATE;다음주 토요일//DEP_TIME;14시/에 출발하는 걸로 수정해줘',
#  '음.. /DATE;11월 23일//DEP_TIME;오후 7시/출발로 바꿔 주세요',
#  '음.. 아니 /DEP_TIME;오후 8시/에 출발하는 걸로 바꿔 줘',
#  '/DATE;다음주 일요일//DEP_TIME;오전 5시/출발로 수정해줘',
#  '아니 /DATE;다음주 수요일//DEP_TIME;11시/에 출발로 바꿀게',
#  '/DEP_TIME;23시/에 출발로 수정할게',
#  '아니 /DATE;5주일 뒤//DEP_TIME;0시/에 출발하는 걸로',
#  '아니 /DATE;5일 뒤//DEP_TIME;6시/에 출발하는 걸로 바꿀게',
#  '아니 /DATE;2일 뒤//DEP_TIME;13시/에 출발하는 걸로 바꿀게',
#  '아니야 /DATE;4주 뒤//DEP_TIME;밤 2시/출발로',
#  '음.. 아니 /DATE;2일 뒤//DEP_TIME;낮 6시/에 출발로 바꿀게',
#  '아니야 /DEP_TIME;새벽 4시/에 출발하는 걸로 바꿀게',
#  '음.. /DEP_TIME;2시/출발로 바꿀게',
#  '아니 /DEP_TIME;새벽 10시/에 출발로 바꿀게',
#  '아니야 /DATE;5주일 뒤//DEP_TIME;11시/에 출발로 수정해줘',
#  '음.. 아니 /DATE;2주일 뒤//DEP_TIME;8시/에 출발로 수정할게',
#  '음.. 아니 /DATE;1주 뒤//DEP_TIME;21시/출발로 바꿔 줘',
#  '아니야 /DATE;2주일 뒤//DEP_TIME;저녁 6시/에 출발로',
#  '/DEP_TIME;0시/에 출발하는 걸로 바꿔 주세요',
#  '음.. 아니 /DEP_TIME;7시/에 출발하는 걸로 수정해줘',
#  '아니야 /DATE;2주일 뒤//DEP_TIME;14시/에 출발로 수정할게',
#  '/DATE;1월 26일//DEP_TIME;4시/에 출발하는 걸로 바꿔 줘',
#  '/DATE;3주 뒤//DEP_TIME;오전 3시/에 출발로 수정할게',
#  '아니야 /DATE;오늘//DEP_TIME;3시/에 출발로 수정해줘',
#  '/DATE;3월 12일//DEP_TIME;아침 6시/에 출발로 수정해줘',
#  '아니야 /DATE;1주 뒤//DEP_TIME;16시/에 출발로 수정할게',
#  '아니 /DATE;오늘//DEP_TIME;14시/에 출발하는 걸로 바꿔 주세요',
#  '음.. /DEP_TIME;1시/에 출발로 바꿔 주세요',
#  '/DATE;다다음주 금요일//DEP_TIME;13시/출발로 수정할게',
#  '아니 /DEP_TIME;18시/에 출발로 수정해줘',
#  '아니 /DATE;다다음주 월요일//DEP_TIME;15시/출발로',
#  '음.. 아니 /DEP_TIME;23시/에 출발하는 걸로 바꿔 줘',
#  '음.. /DATE;오늘//DEP_TIME;8시/에 출발하는 걸로',
#  '음.. /DATE;5일 뒤//DEP_TIME;7시/에 출발하는 걸로 수정할게',
#  '음.. 아니 /DATE;다다음주 화요일//DEP_TIME;낮 6시/출발로 수정할게',
#  '아니야 /DATE;2일 뒤//DEP_TIME;밤 2시/에 출발로 바꿔 줘',
#  '/DEP_TIME;오전 11시/출발로 수정해줘',
#  '음.. 아니 /DATE;다다음주 일요일//DEP_TIME;낮 8시/에 출발하는 걸로 수정해줘',
#  '/DATE;익일//DEP_TIME;14시/에 출발하는 걸로',
#  '/DATE;1주일 뒤//DEP_TIME;밤 6시/출발로 수정할게',
#  '음.. /DATE;다음주 일요일//DEP_TIME;16시/출발로 바꿀게',
#  '아니야 /DATE;9월 30일//DEP_TIME;낮 1시/에 출발하는 걸로 바꿀게',
#  '음.. 아니 /DATE;금일//DEP_TIME;23시/에 출발하는 걸로 수정할게',
#  '음.. /DATE;2일 뒤//DEP_TIME;20시/출발로 바꿀게',
#  '아니 /DATE;4월 20일//DEP_TIME;6시/에 출발하는 걸로 수정해줘',
#  '음.. 아니 /DATE;8월 18일//DEP_TIME;10시/에 출발로 수정해줘',
#  '/DATE;3주 뒤//DEP_TIME;오전 2시/에 출발로 수정해줘',
#  '음.. 아니 /DATE;3주일 뒤//DEP_TIME;23시/에 출발하는 걸로',
#  '/DATE;다다음주 금요일//DEP_TIME;낮 5시/에 출발하는 걸로 바꿔 줘',
#  '/DATE;12월 11일//DEP_TIME;아침 1시/에 출발로 바꿀게',
#  '/DATE;2주일 뒤//DEP_TIME;14시/에 출발로 바꿔 주세요',
#  '아니 /DATE;다다음주 금요일//DEP_TIME;밤 9시/출발로 수정할게',
#  '아니 /DATE;5주일 뒤//DEP_TIME;17시/에 출발로',
#  '음.. 아니 /DATE;1월 4일//DEP_TIME;오전 2시/에 출발로 바꿀게',
#  '아니야 /DATE;금일//DEP_TIME;16시/에 출발하는 걸로 수정해줘',
#  '아니 /DATE;3일 뒤//DEP_TIME;낮 1시/에 출발로 수정할게',
#  '음.. /DATE;다다음주 화요일//DEP_TIME;18시/에 출발하는 걸로 수정할게',
#  '/DATE;3주 뒤//DEP_TIME;23시/에 출발하는 걸로 바꿔 주세요',
#  '아니야 /DATE;다다음주 토요일//DEP_TIME;9시/에 출발하는 걸로 수정할게',
#  '아니야 /DATE;오늘//DEP_TIME;0시/에 출발로 바꿔 주세요',
#  '음.. 아니 /DEP_TIME;밤 6시/에 출발로 바꿔 주세요',
#  '음.. 아니 /DEP_TIME;20시/출발로',
#  '아니야 /DATE;내일//DEP_TIME;저녁 6시/출발로 바꿀게',
#  '아니야 /DEP_TIME;19시/에 출발로 바꿀게',
#  '/DATE;다음주 수요일//DEP_TIME;오후 11시/에 출발하는 걸로 바꿔 줘',
#  '아니야 /DATE;5주 뒤//DEP_TIME;밤 3시/에 출발로',
#  '아니 /DEP_TIME;오후 2시/에 출발로',
#  '음.. 아니 /DEP_TIME;6시/에 출발로 바꿀게',
#  '음.. 아니 /DEP_TIME;9시/에 출발로',
#  '음.. /DEP_TIME;저녁 5시/에 출발로 수정해줘',
#  '음.. /DEP_TIME;1시/에 출발하는 걸로 바꿀게',
#  '아니 /DATE;다음주 일요일//DEP_TIME;16시/에 출발하는 걸로 바꿔 줘',
#  '/DATE;4일 뒤//DEP_TIME;저녁 9시/출발로 바꿀게',
#  '음.. 아니 /DATE;다음주 목요일//DEP_TIME;5시/출발로 수정해줘',
#  '아니야 /DATE;2주일 뒤//DEP_TIME;20시/에 출발하는 걸로 수정해줘',
#  '아니 /DEP_TIME;15시/에 출발하는 걸로 바꿔 주세요',
#  '아니야 /DATE;금일//DEP_TIME;20시/출발로 바꿔 주세요',
#  '아니 /DATE;2일 뒤//DEP_TIME;저녁 9시/출발로 수정할게',
#  '아니 /DEP_TIME;밤 1시/에 출발로 바꿔 줘',
#  '/DEP_TIME;9시/에 출발로 바꿀게',
#  '아니야 /DEP_TIME;13시/에 출발로 수정해줘',
#  '/DEP_TIME;10시/출발로 수정해줘',
#  '/DATE;다음주 화요일//DEP_TIME;22시/에 출발하는 걸로 바꿔 주세요',
#  '/DATE;8월 27일//DEP_TIME;9시/출발로 수정할게',
#  '/DEP_TIME;10시/에 출발하는 걸로 바꿔 주세요',
#  '/DATE;9월 16일//DEP_TIME;새벽 7시/출발로 수정해줘',
#  '아니 /DEP_TIME;아침 6시/에 출발하는 걸로 바꿔 주세요',
#  '아니 /DEP_TIME;아침 4시/출발로 바꿔 주세요',
#  '음.. 아니 /DEP_TIME;밤 7시/에 출발하는 걸로 수정해줘',
#  '아니야 /DATE;이번주 목요일//DEP_TIME;오전 11시/에 출발하는 걸로 바꿔 주세요',
#  '음.. /DATE;익일//DEP_TIME;0시/에 출발하는 걸로 바꿀게',
#  '아니야 /DATE;다음주 일요일//DEP_TIME;오전 9시/에 출발로 바꿔 줘',
#  '/DEP_TIME;오전 11시/에 출발로 바꿀게',
#  '아니야 /DATE;4주일 뒤//DEP_TIME;7시/출발로 수정해줘',
#  '아니야 /DATE;보름//DEP_TIME;15시/에 출발하는 걸로 바꿔 주세요',
#  '음.. 아니 /DATE;3주 뒤//DEP_TIME;23시/출발로 수정할게',
#  '음.. 아니 /DEP_TIME;오전 2시/에 출발하는 걸로',
#  '음.. /DATE;이번주 월요일//DEP_TIME;저녁 10시/에 출발로 바꿔 줘',
#  '아니 /DATE;6월 4일//DEP_TIME;20시/에 출발하는 걸로 수정해줘',
#  '음.. /DATE;다음주 화요일//DEP_TIME;밤 2시/출발로',
#  '음.. /DATE;7월 22일//DEP_TIME;21시/출발로 수정해줘',
#  '아니 /DEP_TIME;1시/에 출발로 수정해줘',
#  '음.. /DATE;다다음주 수요일//DEP_TIME;오전 1시/에 출발로 수정할게',
#  '음.. /DATE;이번주 월요일//DEP_TIME;4시/출발로 바꿔 줘',
#  '음.. /DATE;2일 뒤//DEP_TIME;밤 11시/출발로 바꿀게',
#  '/DATE;이번주 토요일//DEP_TIME;아침 1시/에 출발로 바꿀게',
#  '음.. 아니 /DATE;내일//DEP_TIME;새벽 7시/에 출발하는 걸로',
#  '음.. /DEP_TIME;20시/에 출발하는 걸로 바꿔 줘',
#  '아니야 /DATE;다다음주 토요일//DEP_TIME;19시/에 출발하는 걸로',
#  '아니 /DEP_TIME;7시/에 출발하는 걸로',
#  '음.. 아니 /DATE;1주일 뒤//DEP_TIME;새벽 6시/에 출발하는 걸로 수정해줘',
#  '음.. 아니 /DATE;내일//DEP_TIME;낮 10시/에 출발로 수정할게',
#  '아니야 /DATE;다다음주 월요일//DEP_TIME;낮 5시/에 출발하는 걸로 수정할게',
#  '아니 /DATE;10월 13일//DEP_TIME;21시/출발로 바꿔 주세요',
#  '/DATE;다다음주 월요일//DEP_TIME;오전 2시/에 출발하는 걸로 바꿀게',
#  '/DATE;7월 29일//DEP_TIME;오전 8시/에 출발로 바꿔 줘',
#  '음.. 아니 /DEP_TIME;12시/에 출발하는 걸로 바꿔 줘',
#  '/DATE;이번주 목요일//DEP_TIME;18시/에 출발하는 걸로 수정할게',
#  '음.. 아니 /DATE;8월 25일//DEP_TIME;15시/에 출발하는 걸로',
#  '/DATE;1주일 뒤//DEP_TIME;낮 10시/에 출발로 바꿔 줘',
#  '음.. 아니 /DATE;2주일 뒤//DEP_TIME;18시/에 출발로 바꿔 주세요',
#  '아니 /DATE;1주 뒤//DEP_TIME;15시/에 출발하는 걸로',
#  '음.. 아니 /DATE;다다음주 월요일//DEP_TIME;밤 1시/에 출발하는 걸로 수정할게',
#  '음.. /DATE;6월 17일//DEP_TIME;오후 10시/출발로 바꿀게',
#  '/DATE;4일 뒤//DEP_TIME;18시/출발로 수정해줘',
#  '/DATE;8월 14일//DEP_TIME;밤 3시/에 출발로 수정해줘',
#  '음.. 아니 /DATE;2주 뒤//DEP_TIME;0시/에 출발로 수정할게',
#  '음.. 아니 /DATE;5주일 뒤//DEP_TIME;9시/에 출발로',
#  '/DATE;5일 뒤//DEP_TIME;오후 9시/출발로 바꿔 줘',
#  '/DEP_TIME;19시/출발로 바꿀게',
#  '아니 /DATE;다음주 일요일//DEP_TIME;16시/출발로 수정해줘',
#  '/DEP_TIME;오전 3시/에 출발로 바꿔 줘',
#  '/DATE;익일//DEP_TIME;아침 6시/에 출발로 수정할게',
#  '/DATE;다다음주 수요일//DEP_TIME;10시/에 출발로 바꿀게',
#  '음.. 아니 /DATE;1주일 뒤//DEP_TIME;낮 11시/에 출발하는 걸로 수정해줘',
#  '음.. /DEP_TIME;0시/출발로 바꿀게',
#  '음.. /DEP_TIME;낮 7시/에 출발로 수정해줘',
#  '아니 /DATE;이번주 일요일//DEP_TIME;아침 1시/에 출발로 바꿀게',
#  '/DATE;다다음주 화요일//DEP_TIME;1시/에 출발하는 걸로 바꿀게',
#  '음.. /DATE;이번주 화요일//DEP_TIME;18시/출발로',
#  '/DATE;5일 뒤//DEP_TIME;8시/출발로 바꿔 주세요',
#  '음.. /DATE;다다음주 목요일//DEP_TIME;새벽 3시/출발로 바꿔 줘',
#  '/DATE;다다음주 토요일//DEP_TIME;4시/에 출발로 바꿔 줘',
#  '아니 /DATE;1주 뒤//DEP_TIME;1시/출발로',
#  '음.. /DATE;5주 뒤//DEP_TIME;16시/에 출발하는 걸로 수정해줘',
#  '음.. 아니 /DEP_TIME;17시/출발로 바꿔 줘',
#  '아니야 /DEP_TIME;0시/출발로 바꿀게',
#  '음.. 아니 /DATE;모레//DEP_TIME;저녁 6시/에 출발로 바꿀게',
#  '음.. 아니 /DATE;9월 4일//DEP_TIME;아침 9시/에 출발로 수정해줘',
#  '/DEP_TIME;15시/출발로 바꿔 줘',
#  '아니 /DEP_TIME;낮 9시/에 출발하는 걸로 바꿔 줘',
#  '음.. /DEP_TIME;오후 8시/에 출발하는 걸로 수정할게',
#  '음.. 아니 /DATE;5주일 뒤//DEP_TIME;아침 4시/에 출발로 바꿔 줘',
#  '음.. 아니 /DATE;다다음주 화요일//DEP_TIME;1시/에 출발로',
#  '아니야 /DATE;명일//DEP_TIME;밤 10시/에 출발로 바꿔 줘',
#  '음.. 아니 /DATE;금일//DEP_TIME;새벽 7시/에 출발로',
#  '음.. 아니 /DATE;다음주 일요일//DEP_TIME;3시/출발로 바꿔 줘',
#  '음.. /DATE;6월 14일//DEP_TIME;21시/출발로 바꿔 주세요',
#  '음.. 아니 /DATE;1주 뒤//DEP_TIME;17시/출발로 수정할게',
#  '음.. 아니 /DATE;다음주 월요일//DEP_TIME;저녁 10시/출발로 수정해줘',
#  '음.. /DATE;6월 14일//DEP_TIME;10시/에 출발로 바꿀게',
#  '아니야 /DEP_TIME;아침 1시/에 출발로 바꿀게',
#  '아니야 /DATE;다음주 수요일//DEP_TIME;오전 1시/에 출발하는 걸로 수정해줘',
#  '/DATE;3주 뒤//DEP_TIME;낮 6시/에 출발하는 걸로 수정해줘',
#  '/DEP_TIME;밤 6시/에 출발하는 걸로 수정해줘',
#  '음.. 아니 /DATE;오늘//DEP_TIME;저녁 10시/출발로 수정해줘',
#  '/DATE;4월 27일//DEP_TIME;19시/에 출발하는 걸로 바꿔 주세요',
#  '아니 /DATE;다음주 월요일//DEP_TIME;22시/출발로 바꿔 주세요',
#  '음.. 아니 /DATE;4월 26일//DEP_TIME;아침 1시/에 출발하는 걸로 수정할게',
#  '음.. /DATE;다다음주 수요일//DEP_TIME;저녁 6시/에 출발로 바꿔 주세요',
#  '아니 /DEP_TIME;밤 11시/출발로',
#  '/DATE;다다음주 화요일//DEP_TIME;새벽 2시/에 출발하는 걸로',
#  '아니야 /DATE;1일 뒤//DEP_TIME;22시/에 출발하는 걸로 바꿀게',
#  '음.. 아니 /DATE;이번주 금요일//DEP_TIME;낮 1시/에 출발하는 걸로 수정해줘',
#  '음.. 아니 /DATE;6월 22일//DEP_TIME;오전 11시/에 출발하는 걸로 바꿔 줘',
#  '아니야 /DEP_TIME;밤 5시/에 출발로 수정할게',
#  '아니야 /DATE;12월 23일//DEP_TIME;9시/에 출발하는 걸로 수정해줘',
#  '아니 /DATE;1일 뒤//DEP_TIME;5시/에 출발로 바꿔 주세요',
#  '/DATE;4주 뒤//DEP_TIME;아침 1시/에 출발하는 걸로 바꿀게',
#  '아니 /DATE;8월 16일//DEP_TIME;저녁 10시/출발로 수정해줘',
#  '/DATE;이번주 금요일//DEP_TIME;저녁 11시/출발로 바꿀게',
#  '아니야 /DATE;4일 뒤//DEP_TIME;밤 3시/출발로 바꿔 주세요',
#  '/DEP_TIME;0시/에 출발하는 걸로 바꿔 주세요',
#  '아니야 /DATE;3주 뒤//DEP_TIME;7시/에 출발하는 걸로 수정해줘',
#  '음.. 아니 /DATE;3월 17일//DEP_TIME;8시/출발로 바꿔 줘',
#  '/DEP_TIME;21시/출발로 바꿔 줘',
#  '아니야 /DATE;금일//DEP_TIME;5시/출발로',
#  '아니야 /DATE;12월 5일//DEP_TIME;13시/에 출발로 수정할게',
#  '아니야 /DATE;금일//DEP_TIME;오전 8시/에 출발로 수정할게',
#  '/DEP_TIME;오전 8시/에 출발하는 걸로 바꿀게',
#  '음.. 아니 /DATE;3주일 뒤//DEP_TIME;오후 3시/에 출발로 수정할게',
#  '아니 /DATE;다음주 화요일//DEP_TIME;새벽 6시/출발로 수정할게',
#  '아니 /DATE;5일 뒤//DEP_TIME;1시/에 출발로 바꿔 줘',
#  '/DEP_TIME;6시/출발로 수정할게',
#  '음.. 아니 /DEP_TIME;12시/에 출발로 바꿔 주세요',
#  '음.. /DEP_TIME;1시/에 출발로 수정할게',
#  '음.. 아니 /DATE;이번주 화요일//DEP_TIME;오전 8시/에 출발로 수정해줘',
#  '아니야 /DATE;이번주 화요일//DEP_TIME;19시/출발로 바꿀게',
#  '아니 /DATE;11월 20일//DEP_TIME;아침 3시/에 출발하는 걸로',
#  '음.. 아니 /DATE;모레//DEP_TIME;23시/에 출발하는 걸로 바꿔 줘',
#  '아니야 /DATE;5일 뒤//DEP_TIME;밤 2시/에 출발로',
#  '음.. /DATE;익일//DEP_TIME;새벽 4시/에 출발로 수정할게',
#  '아니야 /DATE;1일 뒤//DEP_TIME;12시/에 출발로 바꿀게',
#  '아니 /DATE;1주일 뒤//DEP_TIME;밤 8시/에 출발하는 걸로 수정할게',
#  '아니야 /DATE;이번주 수요일//DEP_TIME;5시/출발로 바꿔 주세요',
#  '아니야 /DEP_TIME;저녁 11시/에 출발하는 걸로 바꿔 주세요',
#  '음.. /DEP_TIME;오전 10시/출발로 수정할게',
#  '음.. 아니 /DATE;이번주 화요일//DEP_TIME;밤 6시/에 출발하는 걸로 바꿔 주세요',
#  '음.. /DEP_TIME;오후 4시/에 출발하는 걸로 바꿀게',
#  '/DATE;다음주 토요일//DEP_TIME;3시/에 출발하는 걸로 수정할게',
#  '음.. /DEP_TIME;1시/출발로 바꿀게',
#  '/DEP_TIME;아침 9시/에 출발하는 걸로 바꿔 주세요',
#  '아니 /DATE;4일 뒤//DEP_TIME;3시/출발로 바꿔 주세요',
#  '아니 /DATE;4주일 뒤//DEP_TIME;4시/에 출발로 바꿔 줘',
#  '아니 /DATE;8월 7일//DEP_TIME;6시/에 출발하는 걸로 수정할게',
#  '음.. /DATE;2주일 뒤//DEP_TIME;오후 8시/에 출발로 바꿀게',
#  '음.. /DATE;2주 뒤//DEP_TIME;6시/에 출발하는 걸로 바꿔 줘',
#  '/DATE;2월 22일//DEP_TIME;오전 4시/에 출발로',
#  '/DEP_TIME;저녁 3시/에 출발하는 걸로 바꿔 주세요',
#  '/DEP_TIME;오전 8시/에 출발로 바꿔 줘',
#  '음.. 아니 /DATE;4주 뒤//DEP_TIME;12시/에 출발로 수정할게',
#  '음.. /DATE;4월 2일//DEP_TIME;16시/에 출발로 바꿔 줘',
#  '/DATE;다음주 수요일//DEP_TIME;저녁 5시/에 출발로',
#  '음.. 아니 /DATE;다음주 수요일//DEP_TIME;낮 4시/에 출발하는 걸로 수정해줘',
#  '아니야 /DEP_TIME;낮 10시/출발로 바꿔 주세요',
#  '음.. 아니 /DEP_TIME;오후 6시/에 출발로 수정할게',
#  '아니야 /DATE;3주 뒤//DEP_TIME;오후 6시/출발로 바꿔 주세요',
#  '아니야 /DATE;다다음주 토요일//DEP_TIME;아침 6시/에 출발하는 걸로 바꿔 줘',
#  '음.. 아니 /DEP_TIME;저녁 7시/에 출발하는 걸로',
#  '아니 /DEP_TIME;오전 4시/에 출발로',
#  '아니야 /DATE;5주 뒤//DEP_TIME;아침 11시/에 출발하는 걸로 바꿔 줘',
#  '음.. /DATE;명일//DEP_TIME;저녁 1시/에 출발하는 걸로 바꿔 주세요',
#  '음.. 아니 /DATE;다음주 토요일//DEP_TIME;23시/출발로 바꿔 주세요',
#  '/DATE;5월 4일//DEP_TIME;8시/출발로 바꿔 줘',
#  '음.. /DATE;5주일 뒤//DEP_TIME;12시/에 출발하는 걸로 바꿀게',
#  '아니야 /DATE;다음주 금요일//DEP_TIME;오후 8시/출발로 바꿔 주세요',
#  '음.. /DEP_TIME;오전 6시/출발로',
#  '음.. /DATE;모레//DEP_TIME;오후 9시/에 출발하는 걸로 바꿔 주세요',
#  '/DEP_TIME;오후 6시/에 출발하는 걸로 수정할게',
#  '음.. 아니 /DATE;이번주 월요일//DEP_TIME;밤 1시/출발로 수정할게',
#  '아니야 /DEP_TIME;저녁 7시/출발로 바꿀게',
#  '/DEP_TIME;오후 4시/출발로 바꿀게',
#  '아니 /DEP_TIME;11시/출발로 바꿔 주세요',
#  '/DEP_TIME;14시/출발로 바꿔 줘',
#  '아니야 /DATE;2일 뒤//DEP_TIME;새벽 8시/출발로 바꿔 줘',
#  '아니 /DATE;명일//DEP_TIME;아침 4시/출발로 바꿀게',
#  '아니 /DEP_TIME;아침 11시/에 출발로 수정해줘',
#  '음.. /DATE;이번주 화요일//DEP_TIME;낮 2시/에 출발로 바꿀게',
#  '음.. /DEP_TIME;8시/에 출발하는 걸로 바꿀게',
#  '음.. /DATE;4월 13일//DEP_TIME;10시/출발로 바꿔 줘',
#  '아니야 /DATE;명일//DEP_TIME;14시/에 출발하는 걸로 수정해줘',
#  '/DATE;내일 모레//DEP_TIME;낮 4시/출발로',
#  '아니야 /DATE;이번주 수요일//DEP_TIME;20시/에 출발로',
#  '아니 /DATE;다음주 목요일//DEP_TIME;아침 8시/출발로 수정해줘',
#  '아니 /DEP_TIME;18시/출발로 바꿔 주세요',
#  '아니야 /DATE;이번주 일요일//DEP_TIME;13시/에 출발로 수정할게',
#  '음.. 아니 /DATE;4일 뒤//DEP_TIME;오전 9시/에 출발로 바꿀게',
#  '음.. /DATE;보름//DEP_TIME;19시/에 출발하는 걸로 수정해줘',
#  '음.. 아니 /DATE;다음주 목요일//DEP_TIME;오후 8시/출발로 바꿔 주세요',
#  '음.. /DATE;이번주 목요일//DEP_TIME;아침 3시/출발로 바꿔 줘',
#  '아니 /DATE;다다음주 일요일//DEP_TIME;20시/에 출발로 수정해줘',
#  '/DATE;다다음주 화요일//DEP_TIME;낮 11시/출발로',
#  '아니야 /DATE;익일//DEP_TIME;새벽 4시/에 출발하는 걸로 바꿔 줘',
#  '음.. /DEP_TIME;낮 2시/에 출발하는 걸로 바꿔 줘',
#  '음.. 아니 /DATE;다다음주 토요일//DEP_TIME;저녁 6시/출발로 수정할게',
#  '음.. /DATE;3주일 뒤//DEP_TIME;13시/에 출발하는 걸로 바꿔 줘',
#  '음.. 아니 /DATE;익일//DEP_TIME;14시/에 출발로 수정할게',
#  '/DEP_TIME;13시/출발로',
#  '아니야 /DEP_TIME;밤 6시/에 출발하는 걸로 바꿀게',
#  '/DEP_TIME;아침 11시/에 출발로',
#  '아니 /DATE;5주 뒤//DEP_TIME;19시/에 출발하는 걸로 바꿔 줘',
#  '음.. /DATE;4주일 뒤//DEP_TIME;15시/에 출발하는 걸로',
#  '/DATE;3주일 뒤//DEP_TIME;1시/출발로 바꿔 주세요',
#  '음.. /DATE;4주 뒤//DEP_TIME;오후 5시/에 출발하는 걸로 수정할게',
#  '/DATE;4주일 뒤//DEP_TIME;16시/에 출발로 수정할게',
#  '아니 /DEP_TIME;새벽 8시/에 출발하는 걸로',
#  '음.. /DATE;3주일 뒤//DEP_TIME;밤 11시/출발로 바꿔 줘',
#  '음.. /DEP_TIME;오후 1시/에 출발하는 걸로 바꿔 줘',
#  '음.. /DATE;다다음주 수요일//DEP_TIME;23시/출발로 바꿀게',
#  '/DATE;이번주 화요일//DEP_TIME;2시/출발로 수정해줘',
#  '아니야 /DATE;다음주 월요일//DEP_TIME;14시/출발로 수정해줘',
#  '/DATE;내일//DEP_TIME;7시/에 출발로 바꿀게',
#  '음.. 아니 /DATE;12월 10일//DEP_TIME;오전 1시/출발로 수정할게',
#  '아니 /DEP_TIME;12시/출발로',
#  '아니야 /DATE;2일 뒤//DEP_TIME;22시/에 출발로',
#  '아니 /DATE;4월 16일//DEP_TIME;저녁 8시/에 출발로 수정해줘',
#  '음.. /DATE;3주 뒤//DEP_TIME;9시/에 출발로 수정할게',
#  '아니야 /DATE;보름//DEP_TIME;저녁 9시/에 출발로 바꿀게',
#  '아니 /DEP_TIME;오전 5시/에 출발하는 걸로 바꿔 줘',
#  '음.. /DATE;10월 3일//DEP_TIME;22시/출발로 바꿔 줘',
#  '아니 /DATE;4주 뒤//DEP_TIME;낮 1시/출발로 바꿔 주세요',
#  '아니 /DEP_TIME;12시/에 출발하는 걸로 바꿔 줘',
#  '/DATE;이번주 목요일//DEP_TIME;6시/출발로',
#  '아니 /DEP_TIME;21시/출발로 바꿔 줘',
#  '음.. 아니 /DATE;다다음주 월요일//DEP_TIME;아침 4시/출발로',
#  '음.. 아니 /DATE;4주일 뒤//DEP_TIME;밤 4시/에 출발로 바꿔 줘',
#  '음.. 아니 /DEP_TIME;밤 2시/에 출발하는 걸로 바꿔 줘',
#  '음.. /DATE;이번주 목요일//DEP_TIME;오후 11시/출발로 수정해줘',
#  '음.. /DATE;1주일 뒤//DEP_TIME;16시/출발로',
#  '/DATE;1일 뒤//DEP_TIME;낮 10시/출발로 바꿔 줘',
#  '음.. /DEP_TIME;5시/에 출발로',
#  '아니야 /DATE;3일 뒤//DEP_TIME;아침 4시/에 출발로 바꿔 줘',
#  '음.. 아니 /DEP_TIME;새벽 2시/에 출발로 바꿀게',
#  '음.. /DEP_TIME;23시/에 출발하는 걸로 바꿔 주세요',
#  '음.. /DATE;3주 뒤//DEP_TIME;18시/에 출발하는 걸로 수정해줘',
#  '/DATE;보름//DEP_TIME;아침 10시/에 출발하는 걸로 바꿔 주세요',
#  '아니야 /DATE;3주 뒤//DEP_TIME;23시/에 출발하는 걸로 바꿔 주세요',
#  '음.. 아니 /DEP_TIME;아침 7시/출발로',
#  '음.. /DATE;다다음주 월요일//DEP_TIME;9시/에 출발로',
#  '아니야 /DATE;이번주 수요일//DEP_TIME;밤 8시/출발로 바꿔 주세요',
#  '음.. 아니 /DATE;다다음주 화요일//DEP_TIME;저녁 10시/에 출발하는 걸로',
#  '음.. 아니 /DATE;모레//DEP_TIME;새벽 11시/출발로 수정할게',
#  '아니야 /DATE;명일//DEP_TIME;새벽 11시/출발로 바꿔 주세요',
#  '/DEP_TIME;오전 3시/에 출발로 수정할게',
#  '아니 /DATE;1주 뒤//DEP_TIME;21시/에 출발로 수정할게',
#  '음.. /DATE;이번주 금요일//DEP_TIME;12시/에 출발로 수정해줘',
#  '/DATE;2일 뒤//DEP_TIME;낮 7시/출발로 수정할게',
#  '아니야 /DATE;3주일 뒤//DEP_TIME;7시/에 출발로 바꿔 주세요',
#  '/DATE;1주 뒤//DEP_TIME;22시/에 출발로 바꿔 주세요',
#  '음.. /DATE;2일 뒤//DEP_TIME;아침 7시/에 출발로',
#  '아니 /DEP_TIME;10시/에 출발하는 걸로 바꿀게',
#  '아니 /DATE;다음주 월요일//DEP_TIME;5시/에 출발로 수정할게',
#  '아니 /DATE;오늘//DEP_TIME;밤 11시/출발로',
#  '아니 /DEP_TIME;낮 3시/에 출발로 바꿀게',
#  '아니야 /DATE;6월 7일//DEP_TIME;저녁 3시/출발로 수정할게',
#  '/DATE;이번주 일요일//DEP_TIME;9시/에 출발로 바꿔 줘',
#  '/DATE;5주 뒤//DEP_TIME;23시/에 출발로',
#  '아니야 /DATE;10월 29일//DEP_TIME;22시/에 출발하는 걸로',
#  '/DEP_TIME;2시/출발로 바꿔 줘',
#  '/DATE;이번주 토요일//DEP_TIME;13시/에 출발하는 걸로',
#  '/DATE;다음주 금요일//DEP_TIME;2시/에 출발하는 걸로 수정할게',
#  '아니 /DEP_TIME;21시/에 출발하는 걸로 바꿀게',
#  '아니야 /DATE;1주 뒤//DEP_TIME;13시/에 출발로',
#  '아니야 /DATE;5주 뒤//DEP_TIME;오전 3시/출발로 수정해줘',
#  '/DATE;5일 뒤//DEP_TIME;아침 7시/에 출발로 수정할게',
#  '/DATE;이번주 목요일//DEP_TIME;아침 6시/출발로 바꿀게',
#  '음.. 아니 /DATE;3주 뒤//DEP_TIME;낮 11시/에 출발하는 걸로 수정해줘',
#  '아니야 /DEP_TIME;밤 10시/출발로 바꿔 주세요',
#  '아니 /DATE;다음주 수요일//DEP_TIME;저녁 9시/출발로 바꿀게',
#  '음.. /DATE;1일 뒤//DEP_TIME;밤 6시/에 출발하는 걸로 바꿀게',
#  '아니 /DATE;12월 26일//DEP_TIME;20시/출발로 수정해줘',
#  '/DEP_TIME;밤 3시/출발로 수정해줘',
#  '/DATE;금일//DEP_TIME;4시/에 출발하는 걸로 바꿔 주세요',
#  '아니야 /DATE;모레//DEP_TIME;14시/에 출발로',
#  '음.. 아니 /DATE;다음주 토요일//DEP_TIME;21시/에 출발하는 걸로 수정할게',
#  '/DATE;다다음주 화요일//DEP_TIME;저녁 2시/에 출발로 수정할게',
#  '음.. 아니 /DEP_TIME;새벽 7시/출발로 수정할게',
#  '/DATE;내일//DEP_TIME;오전 5시/에 출발로 바꿔 주세요',
#  '음.. 아니 /DEP_TIME;오후 5시/출발로 수정할게',
#  '음.. 아니 /DEP_TIME;아침 10시/에 출발하는 걸로 바꿔 주세요',
#  '음.. /DEP_TIME;19시/에 출발하는 걸로 수정할게',
#  '음.. /DATE;다음주 월요일//DEP_TIME;아침 2시/출발로 바꿔 주세요',
#  '음.. /DATE;다다음주 화요일//DEP_TIME;새벽 10시/에 출발로 수정할게',
#  '음.. 아니 /DATE;이번주 월요일//DEP_TIME;아침 9시/출발로 바꿀게',
#  '아니 /DATE;3주일 뒤//DEP_TIME;4시/에 출발로 수정해줘',
#  '/DATE;내일 모레//DEP_TIME;19시/에 출발하는 걸로 바꿔 주세요',
#  '/DATE;오늘//DEP_TIME;2시/에 출발하는 걸로',
#  '음.. 아니 /DATE;11월 9일//DEP_TIME;새벽 4시/에 출발하는 걸로 바꿀게',
#  '아니야 /DATE;이번주 화요일//DEP_TIME;7시/에 출발로 바꿔 주세요',
#  '/DEP_TIME;19시/에 출발하는 걸로 수정해줘',
#  '아니 /DATE;내일 모레//DEP_TIME;밤 5시/출발로',
#  '아니야 /DATE;3일 뒤//DEP_TIME;16시/에 출발하는 걸로 바꿔 줘',
#  '아니 /DATE;다음주 화요일//DEP_TIME;저녁 7시/출발로 바꿀게',
#  '/DATE;이번주 금요일//DEP_TIME;8시/에 출발로 수정할게',
#  '음.. /DATE;이번주 일요일//DEP_TIME;11시/에 출발로 수정할게',
#  '아니 /DATE;이번주 월요일//DEP_TIME;4시/출발로 바꿀게',
#  '음.. /DATE;다음주 금요일//DEP_TIME;21시/에 출발로 바꿀게',
#  '아니 /DATE;금일//DEP_TIME;17시/에 출발로 수정할게',
#  '음.. /DATE;3주일 뒤//DEP_TIME;22시/에 출발로 수정할게',
#  '음.. /DATE;다음주 금요일//DEP_TIME;낮 5시/에 출발하는 걸로 수정해줘',
#  '음.. /DATE;1주일 뒤//DEP_TIME;16시/출발로 수정해줘',
#  '아니야 /DATE;5주 뒤//DEP_TIME;12시/에 출발하는 걸로 바꿔 줘',
#  '/DEP_TIME;4시/출발로 바꿀게',
#  '/DATE;4월 17일//DEP_TIME;저녁 1시/출발로 바꿔 주세요',
#  '아니야 /DATE;내일//DEP_TIME;새벽 2시/에 출발하는 걸로 수정할게',
#  '아니야 /DATE;1주 뒤//DEP_TIME;6시/에 출발로',
#  '음.. /DEP_TIME;17시/에 출발하는 걸로',
#  '음.. /DATE;이번주 월요일//DEP_TIME;23시/출발로 수정할게',
#  '음.. /DATE;다다음주 토요일//DEP_TIME;아침 2시/출발로 수정할게',
#  '아니 /DATE;4주일 뒤//DEP_TIME;23시/에 출발하는 걸로 바꿀게',
#  '/DATE;다다음주 토요일//DEP_TIME;23시/에 출발하는 걸로 수정해줘',
#  '아니 /DATE;다음주 토요일//DEP_TIME;16시/출발로 바꿔 줘',
#  '음.. 아니 /DATE;다음주 토요일//DEP_TIME;새벽 2시/에 출발하는 걸로 바꿔 줘',
#  '/DATE;1주 뒤//DEP_TIME;새벽 11시/에 출발하는 걸로 수정해줘',
#  '음.. 아니 /DEP_TIME;새벽 1시/출발로',
#  '/DATE;7월 25일//DEP_TIME;14시/출발로 수정할게',
#  '아니 /DATE;1월 7일//DEP_TIME;새벽 6시/에 출발하는 걸로 바꿔 주세요',
#  '/DATE;4주 뒤//DEP_TIME;저녁 7시/출발로 수정할게',
#  '아니야 /DATE;6월 28일//DEP_TIME;오전 5시/에 출발로 수정할게',
#  '/DEP_TIME;오전 9시/출발로 바꿔 주세요',
#  '음.. /DATE;1일 뒤//DEP_TIME;오후 5시/에 출발로 수정할게',
#  '음.. 아니 /DATE;이번주 월요일//DEP_TIME;18시/출발로 수정해줘',
#  '아니 /DATE;4주일 뒤//DEP_TIME;13시/에 출발로 바꿔 줘',
#  '음.. /DEP_TIME;아침 3시/에 출발하는 걸로 바꿀게',
#  '음.. 아니 /DATE;5주일 뒤//DEP_TIME;오전 5시/출발로 바꿔 줘',
#  '음.. /DEP_TIME;8시/출발로 수정할게',
#  '아니 /DATE;이번주 수요일//DEP_TIME;10시/출발로',
#  '음.. /DATE;3주 뒤//DEP_TIME;저녁 5시/에 출발하는 걸로',
#  '/DATE;2주 뒤//DEP_TIME;19시/에 출발하는 걸로 바꿔 줘',
#  '아니야 /DATE;5일 뒤//DEP_TIME;3시/에 출발로 바꿔 주세요',
#  '아니 /DATE;3주 뒤//DEP_TIME;1시/에 출발로 수정할게',
#  '/DATE;1일 뒤//DEP_TIME;아침 6시/에 출발로 바꿔 줘',
#  '/DATE;익일//DEP_TIME;3시/출발로',
#  '/DATE;이번주 목요일//DEP_TIME;오전 4시/에 출발하는 걸로',
#  '음.. /DEP_TIME;3시/출발로 바꿀게',
#  '아니 /DATE;2주 뒤//DEP_TIME;낮 8시/에 출발하는 걸로 수정할게',
#  '/DATE;1주 뒤//DEP_TIME;1시/에 출발로 바꿀게',
#  '음.. 아니 /DATE;금일//DEP_TIME;17시/에 출발하는 걸로 수정할게',
#  '아니야 /DATE;11월 12일//DEP_TIME;새벽 7시/에 출발로 수정해줘',
#  '/DATE;이번주 수요일//DEP_TIME;오후 6시/에 출발하는 걸로 바꿔 주세요',
#  '아니야 /DEP_TIME;낮 8시/에 출발하는 걸로 바꿔 줘',
#  '아니야 /DEP_TIME;오전 6시/에 출발로 바꿔 줘',
#  '음.. /DATE;1주 뒤//DEP_TIME;낮 1시/에 출발하는 걸로 바꿔 줘',
#  '음.. /DATE;다음주 화요일//DEP_TIME;새벽 8시/에 출발로 바꿀게',
#  '음.. 아니 /DATE;모레//DEP_TIME;아침 10시/에 출발하는 걸로 수정해줘',
#  '음.. 아니 /DATE;보름//DEP_TIME;15시/출발로 수정해줘',
#  '음.. 아니 /DEP_TIME;오전 1시/출발로 바꿔 주세요',
#  '아니야 /DATE;4일 뒤//DEP_TIME;오후 7시/에 출발로 수정할게',
#  '음.. 아니 /DATE;5주일 뒤//DEP_TIME;오후 4시/에 출발로 수정해줘',
#  '음.. /DATE;익일//DEP_TIME;저녁 9시/출발로 수정해줘',
#  '아니 /DATE;5주일 뒤//DEP_TIME;낮 5시/에 출발하는 걸로 바꿔 줘',
#  '/DEP_TIME;12시/출발로',
#  '아니야 /DATE;이번주 토요일//DEP_TIME;밤 3시/에 출발하는 걸로 바꿀게',
#  '아니 /DEP_TIME;새벽 8시/에 출발하는 걸로 수정해줘',
#  '아니야 /DATE;다다음주 목요일//DEP_TIME;오후 5시/에 출발로 수정할게',
#  '/DATE;다다음주 수요일//DEP_TIME;오전 9시/에 출발하는 걸로 수정할게',
#  '음.. /DATE;3일 뒤//DEP_TIME;아침 2시/출발로',
#  '아니 /DATE;4주일 뒤//DEP_TIME;오후 6시/출발로 바꿔 주세요',
#  '/DATE;다음주 월요일//DEP_TIME;7시/출발로',
#  '/DATE;1월 2일//DEP_TIME;9시/에 출발하는 걸로 바꿀게',
#  '음.. /DATE;2주일 뒤//DEP_TIME;9시/에 출발하는 걸로 수정할게',
#  '아니야 /DATE;다다음주 화요일//DEP_TIME;11시/출발로 수정해줘',
#  '/DATE;5주일 뒤//DEP_TIME;22시/에 출발하는 걸로',
#  '아니야 /DATE;보름//DEP_TIME;17시/출발로 수정할게',
#  '음.. /DATE;다음주 일요일//DEP_TIME;저녁 1시/출발로',
#  '/DEP_TIME;오후 4시/에 출발하는 걸로 수정할게',
#  '아니 /DEP_TIME;19시/에 출발로 수정할게',
#  '아니 /DATE;2일 뒤//DEP_TIME;8시/에 출발하는 걸로 바꿀게',
#  '아니 /DATE;8월 5일//DEP_TIME;저녁 2시/에 출발로 바꿀게',
#  '아니야 /DATE;4주일 뒤//DEP_TIME;23시/에 출발로 수정할게',
#  '아니 /DATE;이번주 월요일//DEP_TIME;아침 10시/출발로 바꿔 주세요',
#  '아니 /DATE;다다음주 금요일//DEP_TIME;0시/출발로 수정할게',
#  '아니야 /DEP_TIME;7시/에 출발하는 걸로 바꿔 줘',
#  '음.. /DATE;다다음주 수요일//DEP_TIME;8시/에 출발로 수정할게',
#  '음.. 아니 /DEP_TIME;저녁 6시/에 출발하는 걸로 수정할게',
#  '음.. 아니 /DATE;다다음주 목요일//DEP_TIME;22시/에 출발하는 걸로',
#  '아니야 /DEP_TIME;밤 9시/에 출발로',
#  '음.. 아니 /DATE;6월 11일//DEP_TIME;밤 4시/출발로',
#  '음.. /DATE;다다음주 토요일//DEP_TIME;오후 8시/출발로 수정할게',
#  '아니 /DATE;익일//DEP_TIME;오전 9시/에 출발로 수정할게',
#  '아니야 /DATE;이번주 목요일//DEP_TIME;23시/에 출발로 바꿀게',
#  '음.. 아니 /DATE;다음주 수요일//DEP_TIME;16시/에 출발하는 걸로',
#  '음.. 아니 /DATE;3월 28일//DEP_TIME;오전 5시/에 출발로 수정할게',
#  '음.. 아니 /DEP_TIME;오전 9시/출발로 수정해줘',
#  '아니 /DATE;다다음주 목요일//DEP_TIME;오전 3시/출발로 바꿀게',
#  '음.. /DATE;다음주 월요일//DEP_TIME;오후 5시/출발로',
#  '/DATE;다음주 월요일//DEP_TIME;새벽 1시/에 출발하는 걸로 바꿀게',
#  '아니야 /DATE;금일//DEP_TIME;14시/에 출발로 바꿀게',
#  '음.. 아니 /DATE;5월 26일//DEP_TIME;저녁 11시/출발로 바꿀게',
#  '음.. 아니 /DEP_TIME;오전 1시/에 출발하는 걸로 바꿔 주세요',
#  '음.. /DATE;보름//DEP_TIME;오후 2시/에 출발로 수정해줘',
#  '음.. /DATE;2주일 뒤//DEP_TIME;9시/출발로 수정할게',
#  '음.. 아니 /DEP_TIME;19시/에 출발하는 걸로 바꿔 줘',
#  '/DATE;2일 뒤//DEP_TIME;낮 6시/에 출발하는 걸로 바꿀게',
#  '/DATE;보름//DEP_TIME;4시/출발로 바꿔 줘',
#  '아니 /DEP_TIME;0시/에 출발하는 걸로 바꿔 주세요',
#  '음.. /DATE;7월 29일//DEP_TIME;오후 6시/에 출발로 바꿀게',
#  '아니 /DATE;4주일 뒤//DEP_TIME;8시/에 출발하는 걸로 수정해줘',
#  '음.. 아니 /DEP_TIME;오후 1시/에 출발로 수정해줘',
#  '음.. 아니 /DEP_TIME;아침 4시/에 출발로 수정해줘',
#  '아니야 /DATE;다다음주 목요일//DEP_TIME;1시/에 출발로 바꿀게',
#  '음.. 아니 /DEP_TIME;새벽 3시/에 출발로 바꿔 줘',
#  '아니 /DEP_TIME;오전 2시/출발로 바꿀게',
#  '음.. 아니 /DATE;4월 19일//DEP_TIME;밤 11시/에 출발로 바꿔 주세요',
#  '/DATE;모레//DEP_TIME;낮 7시/출발로 바꿔 주세요',
#  '아니 /DATE;다다음주 월요일//DEP_TIME;8시/출발로 수정해줘',
#  '/DATE;다음주 일요일//DEP_TIME;오후 6시/에 출발하는 걸로 수정할게',
#  '음.. 아니 /DATE;오늘//DEP_TIME;오전 5시/에 출발하는 걸로 수정할게',
#  '/DEP_TIME;오전 5시/에 출발하는 걸로 바꿔 줘',
#  '아니야 /DATE;내일 모레//DEP_TIME;아침 2시/에 출발하는 걸로 바꿀게',
#  '아니야 /DATE;다다음주 월요일//DEP_TIME;저녁 4시/출발로',
#  '음.. /DATE;이번주 화요일//DEP_TIME;9시/출발로 수정할게',
#  '음.. /DATE;9월 3일//DEP_TIME;밤 10시/출발로 바꿔 주세요',
#  '아니 /DATE;5일 뒤//DEP_TIME;저녁 9시/에 출발로 수정해줘',
#  '아니야 /DATE;1주 뒤//DEP_TIME;4시/에 출발하는 걸로 수정해줘',
#  '음.. /DATE;7월 28일//DEP_TIME;밤 5시/출발로 수정해줘',
#  '음.. /DATE;다음주 일요일//DEP_TIME;9시/에 출발로 수정해줘',
#  '아니야 /DATE;모레//DEP_TIME;오전 8시/에 출발하는 걸로 수정해줘',
#  '아니야 /DATE;3일 뒤//DEP_TIME;저녁 11시/에 출발하는 걸로 수정해줘',
#  '/DEP_TIME;저녁 6시/출발로',
#  '음.. /DEP_TIME;저녁 4시/에 출발로 수정해줘',
#  '아니야 /DATE;명일//DEP_TIME;9시/에 출발로 바꿀게',
#  '음.. /DATE;다음주 화요일//DEP_TIME;4시/출발로 수정할게',
#  '/DATE;내일//DEP_TIME;밤 6시/에 출발하는 걸로 수정해줘',
#  '아니야 /DATE;이번주 월요일//DEP_TIME;12시/에 출발하는 걸로 수정할게',
#  '음.. 아니 /DATE;5주일 뒤//DEP_TIME;23시/에 출발로 수정해줘',
#  '아니 /DEP_TIME;오후 11시/에 출발로 바꿔 줘',
#  '아니야 /DATE;3월 14일//DEP_TIME;11시/에 출발하는 걸로 바꿔 주세요',
#  '아니 /DEP_TIME;낮 7시/에 출발로 바꿀게',
#  '음.. /DATE;6월 3일//DEP_TIME;21시/에 출발하는 걸로',
#  '음.. 아니 /DATE;3주 뒤//DEP_TIME;아침 2시/에 출발하는 걸로 바꿔 주세요',
#  '아니 /DATE;다음주 화요일//DEP_TIME;14시/출발로 바꿔 주세요',
#  '음.. /DATE;1주일 뒤//DEP_TIME;새벽 6시/출발로 바꿀게',
#  '아니 /DATE;5월 9일//DEP_TIME;1시/출발로 바꿀게',
#  '아니 /DEP_TIME;3시/에 출발하는 걸로 바꿔 주세요',
#  '음.. 아니 /DATE;5주일 뒤//DEP_TIME;새벽 9시/에 출발하는 걸로 수정해줘',
#  '/DATE;3일 뒤//DEP_TIME;13시/출발로 수정할게',
#  '아니야 /DATE;내일//DEP_TIME;0시/출발로 바꿔 줘',
#  '음.. /DATE;금일//DEP_TIME;13시/에 출발로 바꿔 주세요',
#  '음.. /DATE;4일 뒤//DEP_TIME;저녁 1시/출발로 바꿔 주세요',
#  '아니야 /DATE;1주일 뒤//DEP_TIME;오전 4시/에 출발로 바꿔 주세요',
#  '아니 /DEP_TIME;아침 11시/에 출발로 바꿀게',
#  '아니야 /DATE;이번주 목요일//DEP_TIME;23시/에 출발하는 걸로 바꿔 주세요',
#  '아니야 /DATE;보름//DEP_TIME;낮 10시/출발로 바꿔 주세요',
#  '음.. 아니 /DATE;1주일 뒤//DEP_TIME;13시/에 출발로 바꿀게',
#  '음.. 아니 /DATE;1주 뒤//DEP_TIME;오전 10시/에 출발로 바꿀게',
#  '/DEP_TIME;저녁 6시/에 출발로 바꿔 줘',
#  '아니야 /DATE;2일 뒤//DEP_TIME;3시/에 출발하는 걸로 바꿔 줘',
#  '아니야 /DATE;3주 뒤//DEP_TIME;새벽 4시/에 출발로',
#  '음.. 아니 /DATE;보름//DEP_TIME;밤 7시/에 출발하는 걸로',
#  '아니 /DATE;4주 뒤//DEP_TIME;오후 11시/에 출발하는 걸로 수정해줘',
#  '음.. 아니 /DATE;명일//DEP_TIME;밤 10시/에 출발로 수정해줘',
#  '음.. /DATE;6월 6일//DEP_TIME;23시/출발로 바꿔 줘',
#  '/DATE;4주 뒤//DEP_TIME;8시/에 출발하는 걸로',
#  '아니 /DATE;다다음주 토요일//DEP_TIME;5시/에 출발로 바꿔 줘',
#  '/DATE;다음주 화요일//DEP_TIME;16시/에 출발하는 걸로 바꿔 주세요',
#  '아니 /DATE;2일 뒤//DEP_TIME;아침 9시/에 출발하는 걸로 바꿔 주세요',
#  '/DEP_TIME;15시/에 출발로',
#  '아니 /DEP_TIME;1시/에 출발로 바꿀게',
#  '음.. /DATE;4주 뒤//DEP_TIME;아침 1시/에 출발하는 걸로',
#  '음.. /DATE;3일 뒤//DEP_TIME;6시/에 출발하는 걸로',
#  '/DATE;3주일 뒤//DEP_TIME;23시/에 출발로 바꿔 주세요',
#  '/DATE;다음주 일요일//DEP_TIME;밤 6시/출발로 수정할게',
#  '아니야 /DATE;5주 뒤//DEP_TIME;오후 5시/출발로 수정해줘',
#  '아니야 /DEP_TIME;오후 6시/에 출발하는 걸로 수정해줘',
#  '음.. /DATE;1주 뒤//DEP_TIME;14시/에 출발하는 걸로 바꿀게',
#  '음.. /DATE;4주일 뒤//DEP_TIME;22시/출발로',
#  '/DATE;1월 6일//DEP_TIME;11시/출발로 수정할게',
#  '음.. 아니 /DATE;다다음주 월요일//DEP_TIME;15시/에 출발하는 걸로 수정해줘',
#  '음.. /DATE;10월 14일//DEP_TIME;저녁 1시/에 출발로 바꿀게',
#  '아니야 /DATE;1주일 뒤//DEP_TIME;밤 3시/에 출발하는 걸로',
#  '아니야 /DATE;9월 25일//DEP_TIME;밤 2시/에 출발하는 걸로 바꿔 주세요',
#  '/DATE;9월 24일//DEP_TIME;4시/출발로 수정할게',
#  '/DATE;2주 뒤//DEP_TIME;저녁 8시/에 출발로 수정할게',
#  '음.. 아니 /DATE;1주일 뒤//DEP_TIME;2시/에 출발로',
#  '음.. /DATE;다다음주 목요일//DEP_TIME;23시/에 출발하는 걸로 바꿀게',
#  '음.. 아니 /DATE;5주일 뒤//DEP_TIME;오후 10시/출발로 바꿔 줘',
#  '음.. 아니 /DATE;9월 13일//DEP_TIME;낮 10시/출발로 바꿔 주세요',
#  '아니야 /DATE;1주일 뒤//DEP_TIME;5시/출발로 바꿔 주세요',
#  '/DATE;다음주 목요일//DEP_TIME;1시/에 출발로 바꿔 줘',
#  '음.. 아니 /DATE;다다음주 일요일//DEP_TIME;6시/에 출발하는 걸로',
#  '아니 /DATE;명일//DEP_TIME;4시/에 출발하는 걸로 바꿔 주세요',
#  '아니 /DATE;다음주 일요일//DEP_TIME;9시/출발로 바꿀게',
#  '음.. 아니 /DATE;2주일 뒤//DEP_TIME;새벽 9시/에 출발하는 걸로',
#  '아니야 /DATE;4일 뒤//DEP_TIME;20시/에 출발로',
#  '음.. 아니 /DATE;2주일 뒤//DEP_TIME;22시/에 출발하는 걸로',
#  '아니야 /DEP_TIME;밤 3시/에 출발로 수정할게',
#  '음.. 아니 /DEP_TIME;22시/에 출발로 수정할게',
#  '음.. /DATE;4주일 뒤//DEP_TIME;아침 9시/출발로 수정할게',
#  '/DATE;4주 뒤//DEP_TIME;14시/에 출발로',
#  '아니 /DEP_TIME;8시/출발로 바꿔 줘',
#  '음.. 아니 /DATE;3월 31일//DEP_TIME;3시/에 출발로 수정해줘',
#  '음.. /DATE;1주 뒤//DEP_TIME;19시/에 출발하는 걸로 수정해줘',
#  '/DATE;12월 23일//DEP_TIME;밤 6시/에 출발로 바꿀게',
#  '음.. /DEP_TIME;아침 2시/에 출발하는 걸로 바꿔 주세요',
#  '/DATE;다음주 토요일//DEP_TIME;밤 5시/에 출발하는 걸로 바꿔 주세요',
#  '아니 /DATE;익일//DEP_TIME;낮 5시/에 출발하는 걸로 수정할게',
#  '아니야 /DEP_TIME;3시/에 출발하는 걸로 바꿀게',
#  '음.. 아니 /DATE;다다음주 토요일//DEP_TIME;아침 10시/출발로',
#  '음.. /DATE;익일//DEP_TIME;1시/출발로 바꿀게',
#  '아니야 /DEP_TIME;새벽 6시/에 출발로 수정해줘',
#  '음.. /DEP_TIME;새벽 10시/에 출발하는 걸로 바꿔 주세요',
#  '음.. /DATE;3주일 뒤//DEP_TIME;오전 4시/에 출발하는 걸로 바꿔 주세요',
#  '음.. 아니 /DATE;3월 27일//DEP_TIME;오후 10시/에 출발하는 걸로 바꿔 주세요',
#  '/DATE;다음주 수요일//DEP_TIME;오전 8시/에 출발하는 걸로 바꿔 줘',
#  '음.. /DATE;4주 뒤//DEP_TIME;2시/에 출발하는 걸로 수정할게',
#  '음.. /DEP_TIME;새벽 1시/에 출발로 수정해줘',
#  '아니 /DATE;다음주 목요일//DEP_TIME;11시/에 출발로',
#  '아니 /DEP_TIME;22시/출발로',
#  '음.. /DEP_TIME;15시/에 출발로 바꿔 줘',
#  '음.. /DATE;이번주 토요일//DEP_TIME;2시/에 출발로 수정해줘',
#  '음.. 아니 /DATE;다음주 수요일//DEP_TIME;새벽 6시/출발로',
#  '음.. /DATE;3주 뒤//DEP_TIME;새벽 6시/에 출발하는 걸로 수정해줘',
#  '음.. /DATE;금일//DEP_TIME;오전 3시/에 출발하는 걸로 수정할게',
#  '아니야 /DATE;2주 뒤//DEP_TIME;밤 6시/에 출발로 수정할게',
#  '음.. /DATE;보름//DEP_TIME;저녁 4시/에 출발하는 걸로 바꿔 줘',
#  '/DATE;이번주 토요일//DEP_TIME;7시/에 출발하는 걸로 바꿔 줘',
#  '음.. /DATE;4일 뒤//DEP_TIME;새벽 10시/에 출발로 수정할게',
#  '아니야 /DEP_TIME;4시/출발로',
#  '/DATE;3일 뒤//DEP_TIME;밤 4시/에 출발로 바꿔 줘',
#  '아니야 /DATE;익일//DEP_TIME;낮 10시/에 출발하는 걸로 수정해줘',
#  '음.. /DATE;1월 5일//DEP_TIME;새벽 8시/에 출발로',
#  '음.. 아니 /DATE;다음주 토요일//DEP_TIME;새벽 10시/출발로 바꿔 줘',
#  '음.. /DATE;4주일 뒤//DEP_TIME;오후 1시/출발로 수정해줘',
#  '아니야 /DATE;이번주 토요일//DEP_TIME;오후 9시/에 출발로 바꿀게',
#  '/DEP_TIME;20시/출발로 바꿀게',
#  '음.. 아니 /DATE;2주일 뒤//DEP_TIME;15시/에 출발로',
#  '아니 /DATE;이번주 수요일//DEP_TIME;2시/에 출발하는 걸로',
#  '음.. /DATE;5일 뒤//DEP_TIME;21시/에 출발로 수정할게',
#  '음.. /DATE;1월 1일//DEP_TIME;4시/출발로 수정할게',
#  '아니야 /DEP_TIME;17시/에 출발하는 걸로',
#  '아니야 /DATE;오늘//DEP_TIME;저녁 4시/에 출발하는 걸로 바꿔 주세요',
#  '음.. /DATE;1일 뒤//DEP_TIME;밤 1시/출발로',
#  '음.. /DATE;2주일 뒤//DEP_TIME;9시/에 출발하는 걸로 수정해줘',
#  '음.. 아니 /DATE;5일 뒤//DEP_TIME;아침 8시/출발로 수정해줘',
#  '/DATE;10월 7일//DEP_TIME;10시/에 출발로 바꿀게',
#  '음.. 아니 /DEP_TIME;8시/에 출발하는 걸로',
#  '음.. 아니 /DATE;다다음주 일요일//DEP_TIME;3시/에 출발로',
#  '아니 /DATE;5주 뒤//DEP_TIME;12시/출발로',
#  '아니야 /DEP_TIME;16시/에 출발하는 걸로',
#  '/DATE;3주일 뒤//DEP_TIME;12시/에 출발로 바꿀게',
#  '아니 /DATE;2주일 뒤//DEP_TIME;저녁 10시/에 출발로 바꿔 주세요',
#  '음.. /DATE;3월 13일//DEP_TIME;새벽 9시/출발로',
#  '/DEP_TIME;낮 4시/에 출발하는 걸로 수정해줘',
#  '아니야 /DATE;8월 18일//DEP_TIME;저녁 11시/에 출발로 수정해줘',
#  '아니야 /DATE;5주 뒤//DEP_TIME;밤 7시/출발로 바꿔 줘',
#  '음.. 아니 /DEP_TIME;낮 5시/에 출발로 수정할게',
#  '아니 /DATE;4주일 뒤//DEP_TIME;3시/출발로',
#  '아니 /DEP_TIME;아침 1시/출발로 수정해줘',
#  '/DATE;명일//DEP_TIME;밤 5시/에 출발로 바꿔 주세요',
#  '/DATE;1월 14일//DEP_TIME;18시/에 출발로 수정해줘',
#  '음.. 아니 /DATE;5주 뒤//DEP_TIME;7시/에 출발하는 걸로',
#  '음.. 아니 /DATE;이번주 수요일//DEP_TIME;낮 11시/에 출발로 수정할게',
#  '아니 /DATE;12월 19일//DEP_TIME;새벽 11시/출발로',
#  '아니 /DATE;다음주 월요일//DEP_TIME;13시/에 출발로 바꿔 줘',
#  '아니야 /DATE;이번주 토요일//DEP_TIME;11시/에 출발로 수정해줘',
#  '음.. 아니 /DATE;이번주 토요일//DEP_TIME;16시/에 출발하는 걸로',
#  '음.. 아니 /DATE;다음주 월요일//DEP_TIME;오후 3시/에 출발하는 걸로 바꿔 주세요',
#  '음.. /DATE;명일//DEP_TIME;6시/출발로',
#  '아니야 /DEP_TIME;아침 10시/출발로 바꿔 줘',
#  '음.. /DATE;다음주 토요일//DEP_TIME;17시/출발로 바꿔 주세요',
#  '음.. 아니 /DEP_TIME;저녁 1시/에 출발하는 걸로 바꿔 줘',
#  '아니야 /DATE;3일 뒤//DEP_TIME;오후 4시/에 출발하는 걸로 수정할게',
#  '아니야 /DATE;2주일 뒤//DEP_TIME;23시/출발로 바꿔 줘',
#  '/DATE;다다음주 목요일//DEP_TIME;6시/에 출발하는 걸로 바꿔 주세요',
#  '음.. /DATE;이번주 일요일//DEP_TIME;14시/에 출발로',
#  '음.. /DEP_TIME;오전 3시/출발로',
#  '음.. 아니 /DATE;다음주 목요일//DEP_TIME;밤 5시/에 출발로 수정할게',
#  '음.. /DATE;이번주 토요일//DEP_TIME;15시/에 출발하는 걸로 바꿀게',
#  '음.. /DEP_TIME;아침 8시/에 출발로',
#  '음.. /DATE;익일//DEP_TIME;10시/출발로 바꿀게',
#  '음.. 아니 /DEP_TIME;8시/출발로',
#  '아니 /DEP_TIME;새벽 4시/에 출발하는 걸로 바꿔 줘',
#  '아니 /DEP_TIME;새벽 5시/에 출발로 바꿔 주세요',
#  '음.. /DATE;4주일 뒤//DEP_TIME;19시/출발로 바꿔 주세요',
#  '음.. /DATE;5주일 뒤//DEP_TIME;낮 11시/출발로 바꿔 줘',
#  '아니 /DATE;다음주 목요일//DEP_TIME;오전 3시/에 출발로 수정해줘',
#  '/DATE;11월 30일//DEP_TIME;낮 9시/에 출발로',
#  '/DATE;이번주 수요일//DEP_TIME;오후 1시/출발로 수정해줘',
#  '/DEP_TIME;오후 10시/에 출발하는 걸로 수정할게',
#  '음.. 아니 /DATE;다음주 월요일//DEP_TIME;14시/에 출발하는 걸로 바꿔 줘',
#  '아니야 /DATE;다음주 화요일//DEP_TIME;1시/에 출발하는 걸로',
#  '음.. 아니 /DEP_TIME;0시/에 출발하는 걸로 바꿀게',
#  '음.. 아니 /DEP_TIME;6시/출발로 바꿔 줘',
#  '아니 /DATE;8월 25일//DEP_TIME;8시/에 출발로 바꿀게',
#  '아니야 /DEP_TIME;아침 7시/출발로 바꿔 줘',
#  '음.. /DEP_TIME;19시/에 출발하는 걸로 바꿔 주세요',
#  '음.. 아니 /DEP_TIME;저녁 9시/에 출발로 바꿔 주세요',
#  '아니야 /DATE;10월 6일//DEP_TIME;3시/출발로 수정해줘',
#  '음.. /DATE;2월 10일//DEP_TIME;저녁 3시/에 출발로 바꿔 주세요',
#  '아니 /DATE;다음주 수요일//DEP_TIME;새벽 10시/출발로 바꿀게',
#  '음.. /DATE;1주 뒤//DEP_TIME;새벽 7시/출발로 수정할게',
#  '아니야 /DATE;명일//DEP_TIME;새벽 8시/출발로',
#  '아니야 /DATE;다음주 목요일//DEP_TIME;새벽 8시/출발로 수정해줘',
#  '음.. /DATE;9월 6일//DEP_TIME;아침 8시/에 출발로 바꿀게',
#  '아니 /DATE;10월 21일//DEP_TIME;저녁 7시/에 출발하는 걸로 수정할게',
#  '아니 /DATE;5주 뒤//DEP_TIME;16시/출발로 수정할게',
#  '아니야 /DATE;11월 28일//DEP_TIME;아침 1시/출발로',
#  '/DATE;8월 23일//DEP_TIME;새벽 10시/에 출발하는 걸로 바꿀게',
#  '/DATE;2주일 뒤//DEP_TIME;오전 10시/에 출발로 수정할게',
#  '/DATE;4주 뒤//DEP_TIME;15시/에 출발로 수정해줘',
#  '아니 /DATE;이번주 금요일//DEP_TIME;새벽 1시/출발로 바꿔 줘',
#  '/DATE;5주일 뒤//DEP_TIME;저녁 9시/에 출발로 바꿔 주세요',
#  '아니 /DATE;4주일 뒤//DEP_TIME;8시/에 출발로 바꿔 줘',
#  '아니야 /DATE;다다음주 토요일//DEP_TIME;낮 5시/출발로 수정해줘',
#  '/DATE;명일//DEP_TIME;13시/에 출발로 바꿔 줘',
#  '음.. /DATE;이번주 수요일//DEP_TIME;22시/에 출발로',
#  '아니야 /DATE;3일 뒤//DEP_TIME;21시/에 출발하는 걸로 수정해줘',
#  '음.. /DATE;다음주 금요일//DEP_TIME;17시/에 출발로 수정해줘',
#  '아니야 /DATE;금일//DEP_TIME;3시/출발로 수정할게',
#  '음.. 아니 /DATE;4월 29일//DEP_TIME;23시/출발로 바꿔 주세요',
#  '아니 /DEP_TIME;오후 11시/출발로',
#  '아니야 /DATE;다다음주 월요일//DEP_TIME;오전 4시/에 출발하는 걸로 바꿀게',
#  '/DATE;명일//DEP_TIME;오전 9시/출발로 바꿀게',
#  '아니야 /DEP_TIME;새벽 6시/출발로 수정해줘',
#  '음.. /DATE;다다음주 토요일//DEP_TIME;새벽 10시/출발로 수정해줘',
#  '음.. 아니 /DATE;다다음주 수요일//DEP_TIME;아침 2시/에 출발하는 걸로 바꿔 주세요',
#  '음.. 아니 /DATE;이번주 토요일//DEP_TIME;새벽 4시/에 출발로 바꿀게',
#  '/DATE;11월 29일//DEP_TIME;7시/에 출발하는 걸로',
#  '아니 /DATE;3일 뒤//DEP_TIME;저녁 4시/에 출발하는 걸로 수정할게',
#  '음.. /DATE;3주일 뒤//DEP_TIME;3시/에 출발로 수정해줘',
#  '아니야 /DATE;1일 뒤//DEP_TIME;새벽 2시/에 출발하는 걸로 바꿔 줘',
#  '음.. /DATE;5일 뒤//DEP_TIME;6시/에 출발로 바꿔 주세요',
#  '/DATE;이번주 화요일//DEP_TIME;저녁 2시/에 출발로 바꿔 줘',
#  '아니야 /DATE;2주일 뒤//DEP_TIME;새벽 8시/출발로 수정해줘',
#  '아니야 /DEP_TIME;7시/에 출발하는 걸로 바꿀게',
#  '음.. 아니 /DEP_TIME;19시/에 출발하는 걸로 수정할게',
#  '아니야 /DATE;9월 15일//DEP_TIME;밤 4시/에 출발하는 걸로',
#  '음.. /DATE;이번주 토요일//DEP_TIME;저녁 11시/에 출발하는 걸로 수정해줘',
#  '아니 /DEP_TIME;11시/에 출발하는 걸로',
#  '아니야 /DATE;5일 뒤//DEP_TIME;7시/출발로 수정해줘',
#  '아니야 /DATE;이번주 수요일//DEP_TIME;6시/출발로 바꿔 줘',
#  '아니 /DEP_TIME;22시/에 출발로 바꿔 줘',
#  '아니야 /DATE;다다음주 월요일//DEP_TIME;오후 1시/에 출발로 수정할게',
#  '아니 /DATE;1주일 뒤//DEP_TIME;저녁 4시/출발로 바꿔 줘',
#  '음.. /DATE;다음주 금요일//DEP_TIME;밤 5시/출발로 바꿔 줘',
#  '아니 /DATE;오늘//DEP_TIME;낮 10시/에 출발하는 걸로 수정할게',
#  '/DATE;다음주 토요일//DEP_TIME;밤 7시/에 출발하는 걸로 바꿔 줘',
#  '음.. 아니 /DATE;다다음주 일요일//DEP_TIME;오전 4시/출발로 수정할게',
#  '/DATE;다음주 목요일//DEP_TIME;18시/출발로 수정해줘',
#  '음.. 아니 /DEP_TIME;15시/에 출발로 수정할게',
#  '아니야 /DEP_TIME;아침 8시/에 출발로 수정해줘',
#  '음.. 아니 /DATE;7월 26일//DEP_TIME;아침 8시/출발로',
#  '음.. 아니 /DATE;1일 뒤//DEP_TIME;아침 10시/에 출발로 바꿀게',
#  '아니 /DATE;내일 모레//DEP_TIME;오전 9시/출발로 바꿔 주세요',
#  '음.. /DATE;이번주 토요일//DEP_TIME;오후 2시/에 출발하는 걸로 바꿔 줘',
#  '아니 /DATE;다음주 월요일//DEP_TIME;낮 7시/에 출발하는 걸로 바꿔 주세요',
#  '아니야 /DATE;5주 뒤//DEP_TIME;낮 1시/에 출발하는 걸로',
#  '아니야 /DATE;다음주 일요일//DEP_TIME;14시/출발로 수정해줘',
#  '아니야 /DATE;4일 뒤//DEP_TIME;2시/출발로 수정할게',
#  '음.. /DEP_TIME;3시/출발로',
#  '/DATE;5주 뒤//DEP_TIME;낮 2시/출발로 바꿀게',
#  '/DEP_TIME;4시/에 출발로 수정해줘',
#  '/DATE;이번주 목요일//DEP_TIME;아침 5시/출발로 바꿀게',
#  '아니 /DATE;8월 23일//DEP_TIME;낮 9시/에 출발로',
#  '음.. /DATE;금일//DEP_TIME;아침 2시/에 출발로 바꿔 줘',
#  '음.. 아니 /DATE;4주 뒤//DEP_TIME;14시/출발로 바꿀게',
#  '아니야 /DATE;8월 2일//DEP_TIME;23시/에 출발로 수정할게',
#  '/DATE;오늘//DEP_TIME;7시/출발로 바꿔 줘',
#  '아니 /DATE;이번주 토요일//DEP_TIME;밤 4시/출발로 바꿀게',
#  '아니 /DATE;보름//DEP_TIME;저녁 9시/에 출발로',
#  '음.. 아니 /DATE;다다음주 화요일//DEP_TIME;오후 3시/출발로 수정해줘',
#  '아니야 /DATE;2주 뒤//DEP_TIME;아침 1시/출발로 바꿔 주세요',
#  '음.. 아니 /DATE;4주일 뒤//DEP_TIME;3시/에 출발하는 걸로 바꿔 주세요',
#  '아니야 /DATE;2주일 뒤//DEP_TIME;1시/에 출발로',
#  '/DATE;다다음주 월요일//DEP_TIME;10시/출발로 수정할게',
#  '아니야 /DEP_TIME;22시/에 출발로 바꿀게',
#  '음.. 아니 /DATE;모레//DEP_TIME;저녁 1시/에 출발로 수정할게',
#  '음.. /DATE;이번주 토요일//DEP_TIME;아침 7시/출발로 수정해줘',
#  '/DATE;2주일 뒤//DEP_TIME;낮 2시/에 출발하는 걸로 바꿔 주세요',
#  '아니 /DEP_TIME;17시/에 출발하는 걸로 바꿀게',
#  '아니야 /DATE;보름//DEP_TIME;밤 4시/에 출발하는 걸로 수정할게',
#  '음.. /DATE;명일//DEP_TIME;5시/출발로 바꿔 줘',
#  '아니 /DATE;내일//DEP_TIME;오전 11시/에 출발로 수정할게',
#  '음.. /DATE;4주일 뒤//DEP_TIME;7시/에 출발하는 걸로 수정해줘',
#  '음.. 아니 /DEP_TIME;낮 6시/에 출발하는 걸로 바꿔 줘',
#  '/DATE;8월 28일//DEP_TIME;저녁 10시/출발로 수정해줘',
#  '아니 /DATE;5주일 뒤//DEP_TIME;밤 5시/에 출발로 수정해줘',
#  '아니야 /DATE;2일 뒤//DEP_TIME;저녁 10시/출발로 수정할게',
#  '아니야 /DATE;이번주 일요일//DEP_TIME;밤 4시/에 출발하는 걸로 바꿔 주세요',
#  '/DEP_TIME;저녁 11시/출발로 수정해줘',
#  '음.. 아니 /DEP_TIME;5시/에 출발하는 걸로 바꿀게',
#  '음.. 아니 /DATE;4주 뒤//DEP_TIME;오전 10시/출발로 바꿀게',
#  '아니 /DEP_TIME;15시/출발로 수정해줘',
#  '아니 /DATE;2월 20일//DEP_TIME;저녁 11시/에 출발하는 걸로 바꿔 줘',
#  '아니 /DEP_TIME;19시/에 출발하는 걸로 바꿔 줘',
#  '아니 /DATE;5주일 뒤//DEP_TIME;7시/에 출발로 바꿀게',
#  '음.. 아니 /DEP_TIME;4시/에 출발하는 걸로',
#  '음.. /DEP_TIME;새벽 9시/에 출발로 수정할게',
#  '음.. 아니 /DATE;다음주 토요일//DEP_TIME;밤 6시/출발로 수정할게',
#  '음.. 아니 /DATE;다음주 화요일//DEP_TIME;17시/에 출발하는 걸로 바꿔 줘',
#  '음.. 아니 /DATE;1일 뒤//DEP_TIME;18시/에 출발하는 걸로 수정할게',
#  '/DEP_TIME;저녁 1시/에 출발하는 걸로 바꿔 주세요',
#  '/DATE;2주 뒤//DEP_TIME;오전 11시/에 출발로 바꿔 주세요',
#  '아니야 /DEP_TIME;4시/에 출발로',
#  '음.. 아니 /DEP_TIME;3시/에 출발로 바꿀게',
#  '음.. 아니 /DATE;오늘//DEP_TIME;16시/에 출발로 바꿔 주세요',
#  '음.. /DATE;금일//DEP_TIME;10시/에 출발로 수정할게',
#  '아니 /DATE;다음주 월요일//DEP_TIME;5시/출발로 바꿀게',
#  '음.. /DATE;이번주 금요일//DEP_TIME;저녁 7시/에 출발로 수정해줘',
#  '음.. 아니 /DATE;보름//DEP_TIME;밤 10시/에 출발로 바꿔 주세요',
#  '음.. 아니 /DATE;3월 19일//DEP_TIME;밤 3시/에 출발로 바꿔 주세요',
#  '아니야 /DATE;4주 뒤//DEP_TIME;오후 5시/에 출발하는 걸로 바꿔 줘',
#  '음.. /DEP_TIME;오전 5시/출발로 바꿔 줘',
#  '음.. /DATE;이번주 일요일//DEP_TIME;9시/출발로',
#  '음.. 아니 /DATE;7월 13일//DEP_TIME;10시/출발로',
#  '음.. 아니 /DEP_TIME;5시/출발로 바꿔 주세요',
#  '/DATE;3주 뒤//DEP_TIME;오전 11시/출발로 수정해줘',
#  '아니 /DATE;1일 뒤//DEP_TIME;17시/에 출발하는 걸로 바꿀게',
#  '/DATE;이번주 토요일//DEP_TIME;저녁 8시/에 출발로 바꿔 줘',
#  '아니 /DATE;다다음주 토요일//DEP_TIME;17시/출발로 수정해줘',
#  '음.. /DEP_TIME;아침 7시/에 출발하는 걸로 바꿀게',
#  '아니야 /DATE;1주일 뒤//DEP_TIME;낮 7시/에 출발로 수정해줘',
#  '음.. 아니 /DATE;6월 3일//DEP_TIME;4시/에 출발로 수정할게',
#  '음.. 아니 /DEP_TIME;낮 5시/에 출발하는 걸로',
#  '아니 /DATE;10월 12일//DEP_TIME;23시/출발로 수정할게',
#  '/DATE;보름//DEP_TIME;밤 5시/출발로 바꿀게',
#  '음.. /DATE;11월 24일//DEP_TIME;2시/에 출발하는 걸로 수정할게',
#  '/DEP_TIME;새벽 9시/에 출발하는 걸로 바꿔 주세요',
#  '아니 /DATE;모레//DEP_TIME;8시/에 출발로 바꿔 줘',
#  '음.. 아니 /DATE;모레//DEP_TIME;11시/에 출발하는 걸로 바꿔 주세요',
#  '음.. /DATE;5일 뒤//DEP_TIME;8시/에 출발하는 걸로',
#  '음.. 아니 /DATE;3주 뒤//DEP_TIME;2시/에 출발로 바꿀게',
#  '아니 /DATE;금일//DEP_TIME;오전 9시/에 출발로 수정할게',
#  '아니야 /DEP_TIME;저녁 7시/에 출발하는 걸로 바꿔 주세요',
#  '음.. 아니 /DATE;다음주 화요일//DEP_TIME;밤 11시/에 출발로 바꿀게',
#  '음.. /DATE;보름//DEP_TIME;낮 10시/에 출발로 바꿔 줘',
#  '아니 /DATE;12월 25일//DEP_TIME;1시/에 출발하는 걸로 바꿔 줘',
#  '아니야 /DATE;4일 뒤//DEP_TIME;오전 8시/에 출발하는 걸로 수정해줘',
#  '/DATE;다음주 일요일//DEP_TIME;아침 1시/에 출발하는 걸로',
#  '/DATE;9월 2일//DEP_TIME;15시/에 출발로 바꿀게',
#  '음.. 아니 /DATE;이번주 토요일//DEP_TIME;10시/에 출발로 바꿔 주세요',
#  '아니야 /DATE;9월 19일//DEP_TIME;1시/에 출발로 수정할게',
#  '음.. /DATE;내일 모레//DEP_TIME;아침 4시/에 출발하는 걸로',
#  '아니 /DEP_TIME;16시/에 출발로 바꿔 줘',
#  '아니야 /DATE;다다음주 월요일//DEP_TIME;새벽 1시/출발로 바꿔 줘',
#  '아니 /DEP_TIME;새벽 8시/에 출발로 수정할게',
#  '음.. /DATE;이번주 토요일//DEP_TIME;5시/에 출발로 바꿔 줘',
#  '음.. 아니 /DEP_TIME;아침 7시/에 출발로 바꿔 줘',
#  '음.. /DATE;명일//DEP_TIME;새벽 8시/에 출발로 바꿔 줘',
#  '음.. 아니 /DATE;6월 22일//DEP_TIME;15시/에 출발하는 걸로 바꿔 줘',
#  '/DATE;4주일 뒤//DEP_TIME;오전 3시/에 출발하는 걸로 수정해줘',
#  '/DATE;명일//DEP_TIME;새벽 1시/출발로 바꿔 줘',
#  '음.. /DEP_TIME;0시/에 출발하는 걸로',
#  '음.. /DATE;8월 26일//DEP_TIME;5시/에 출발로 바꿔 줘',
#  '아니 /DATE;2일 뒤//DEP_TIME;오전 3시/에 출발로 수정해줘',
#  '음.. /DATE;모레//DEP_TIME;9시/에 출발로 바꿀게',
#  '아니 /DATE;5주일 뒤//DEP_TIME;오전 8시/출발로 바꿔 줘',
#  '음.. 아니 /DATE;모레//DEP_TIME;저녁 11시/에 출발하는 걸로 바꿔 줘',
#  '음.. 아니 /DATE;다다음주 일요일//DEP_TIME;저녁 5시/출발로 수정할게',
#  '음.. /DATE;12월 7일//DEP_TIME;20시/에 출발하는 걸로',
#  '아니야 /DATE;다음주 목요일//DEP_TIME;오후 3시/에 출발하는 걸로 바꿀게',
#  '아니야 /DATE;다다음주 금요일//DEP_TIME;13시/출발로 수정할게',
#  '아니야 /DEP_TIME;오후 11시/에 출발로 바꿀게',
#  '아니야 /DATE;다다음주 월요일//DEP_TIME;11시/에 출발로 바꿔 줘',
#  '음.. 아니 /DATE;이번주 토요일//DEP_TIME;낮 2시/에 출발하는 걸로 수정할게',
#  '/DEP_TIME;오후 2시/에 출발하는 걸로 바꿔 주세요',
#  '음.. /DATE;다음주 토요일//DEP_TIME;저녁 11시/에 출발하는 걸로',
#  '아니 /DATE;11월 8일//DEP_TIME;20시/에 출발하는 걸로 바꿔 주세요',
#  '음.. /DATE;다다음주 일요일//DEP_TIME;5시/에 출발하는 걸로 수정할게',
#  '음.. /DATE;이번주 화요일//DEP_TIME;낮 8시/출발로',
#  '/DEP_TIME;아침 4시/에 출발하는 걸로',
#  '아니야 /DATE;5주 뒤//DEP_TIME;오전 10시/출발로 바꿔 주세요',
#  '음.. /DATE;2주 뒤//DEP_TIME;아침 5시/에 출발하는 걸로 수정할게',
#  '음.. /DEP_TIME;아침 9시/에 출발하는 걸로',
#  '아니 /DATE;3주 뒤//DEP_TIME;18시/에 출발로 바꿔 줘',
#  '음.. /DEP_TIME;15시/에 출발하는 걸로 바꿔 주세요',
#  '아니 /DATE;다음주 금요일//DEP_TIME;20시/출발로',
#  '음.. /DATE;다음주 화요일//DEP_TIME;14시/출발로 바꿔 줘',
#  '/DEP_TIME;오전 4시/에 출발로 바꿔 줘',
#  '/DATE;이번주 토요일//DEP_TIME;12시/에 출발로 바꿔 주세요',
#  '음.. /DEP_TIME;18시/에 출발로 바꿀게',
#  '아니야 /DEP_TIME;7시/에 출발로 바꿔 줘',
#  '아니 /DATE;12월 31일//DEP_TIME;새벽 8시/출발로 바꿀게',
#  '아니 /DATE;이번주 금요일//DEP_TIME;저녁 1시/에 출발하는 걸로 수정해줘',
#  '아니 /DATE;2주 뒤//DEP_TIME;오전 5시/에 출발로',
#  '아니야 /DEP_TIME;18시/에 출발하는 걸로 바꿔 줘',
#  '음.. /DATE;다다음주 목요일//DEP_TIME;17시/출발로',
#  '아니야 /DATE;이번주 월요일//DEP_TIME;8시/출발로 수정할게',
#  '/DEP_TIME;밤 1시/에 출발하는 걸로 바꿀게',
#  '음.. 아니 /DATE;4주 뒤//DEP_TIME;20시/출발로',
#  '음.. /DATE;12월 27일//DEP_TIME;낮 3시/에 출발하는 걸로 수정해줘',
#  '아니 /DATE;다음주 수요일//DEP_TIME;낮 6시/에 출발로',
#  '/DATE;이번주 수요일//DEP_TIME;10시/에 출발로 수정할게',
#  '아니 /DATE;오늘//DEP_TIME;밤 10시/에 출발하는 걸로',
#  '음.. 아니 /DATE;다음주 화요일//DEP_TIME;저녁 3시/에 출발하는 걸로 바꿔 주세요',
#  '아니 /DATE;4주일 뒤//DEP_TIME;저녁 7시/출발로 바꿀게',
#  '아니야 /DATE;1주일 뒤//DEP_TIME;0시/출발로 수정할게',
#  '음.. 아니 /DATE;보름//DEP_TIME;5시/출발로 바꿀게',
#  '/DATE;10월 18일//DEP_TIME;17시/에 출발하는 걸로',
#  '아니 /DATE;3주 뒤//DEP_TIME;9시/에 출발로 바꿔 줘',
#  '아니야 /DATE;2주 뒤//DEP_TIME;밤 11시/에 출발로 수정할게',
#  '아니야 /DATE;다음주 월요일//DEP_TIME;22시/에 출발하는 걸로 수정해줘',
#  '아니 /DATE;7월 30일//DEP_TIME;7시/출발로 수정할게',
#  '/DATE;2주 뒤//DEP_TIME;오후 3시/출발로',
#  '음.. 아니 /DATE;다다음주 화요일//DEP_TIME;8시/에 출발하는 걸로 바꿀게',
#  '음.. /DATE;1일 뒤//DEP_TIME;저녁 11시/에 출발로 바꿀게',
#  '아니야 /DATE;익일//DEP_TIME;아침 6시/에 출발하는 걸로 바꿀게',
#  '음.. /DATE;2일 뒤//DEP_TIME;0시/에 출발하는 걸로 수정해줘',
#  '/DATE;내일//DEP_TIME;밤 8시/에 출발로',
#  '아니 /DEP_TIME;16시/출발로 바꿔 주세요',
#  '아니 /DATE;12월 23일//DEP_TIME;1시/에 출발하는 걸로',
#  '아니 /DATE;다다음주 수요일//DEP_TIME;3시/출발로 바꿀게',
#  '아니 /DATE;다다음주 금요일//DEP_TIME;저녁 8시/에 출발하는 걸로 바꿔 주세요',
#  '아니 /DATE;다다음주 일요일//DEP_TIME;7시/에 출발하는 걸로 바꿔 주세요',
#  '아니 /DATE;10월 8일//DEP_TIME;저녁 3시/에 출발하는 걸로',
#  '음.. 아니 /DATE;5일 뒤//DEP_TIME;19시/에 출발로',
#  ...]
